# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)

# %%
all_muts_df = pd.read_pickle("../data/4_10_with_uniq_midpts.pkl")
print(len(all_muts_df))
all_muts_df.head()
# Out:
# 3921
#   index  exp  ale  flask  isolate  tech_rep  presence  Position Mutation Type  \
# 0     9  42C    1    124        1         1       1.0    702352           DEL
# 1    10  42C    1    124        1         1       1.0   1308318           SNP
# 2    11  42C    1    124        1         1       1.0   3815859           DEL
# 3    12  42C    1    124        1         1       1.0   4187550           SNP
# 4    13  42C    1    124        1         1       1.0   4400313           SNP
#
#   Sequence Change                   Details mutation target annotation  \
# 0          Δ21 bp  coding (380‑400/1149 nt)                       nagA
# 1             G→C           R110G (CGT→GGT)                       clsA
# 2          Δ82 bp                      None                        rph
# 3             C→T           A734V (GCG→GTG)                       rpoC
# 4             A→C             D9A (GAT→GCT)                        hfq
#
#   Reference Seq     sample sample type exp ALE  coding               range  \
# 0           NaN  1 124 1 1       clone   42C 1    True    (702352, 702372)
# 1           NaN  1 124 1 1       clone   42C 1    True  (1308318, 1308318)
# 2           NaN  1 124 1 1       clone   42C 1    True  (3815859, 3815940)
# 3           NaN  1 124 1 1       clone   42C 1    True  (4187550, 4187550)
# 4           NaN  1 124 1 1       clone   42C 1    True  (4400313, 4400313)
#
#   gene RegulonDB ID                                   genetic features   oriC  \
# 0    {ECK120000625}  [{'name': 'nagA', 'RegulonDB ID': 'ECK12000062...  False
# 1    {ECK120001556}  [{'name': 'clsA', 'RegulonDB ID': 'ECK12000155...  False
# 2    {ECK120000854}  [{'name': 'rph', 'RegulonDB ID': 'ECK120000854...  False
# 3    {ECK120000886}  [{'name': 'rpoC', 'RegulonDB ID': 'ECK12000088...  False
# 4    {ECK120000431}  [{'name': 'hfq', 'RegulonDB ID': 'ECK120000431...  False
#
#    pseudogene TFBS promoter RBS attenuator terminator terminator  genetic  \
# 0       False   {}       {}  {}                    {}         {}     True
# 1       False   {}       {}  {}                    {}         {}     True
# 2       False   {}       {}  {}        {ECK125144791}         {}     True
# 3       False   {}       {}  {}                    {}         {}     True
# 4       False   {}       {}  {}                    {}         {}     True
#
#                                     genomic features  \
# 0  [{'name': 'nagA', 'RegulonDB ID': 'ECK12000062...
# 1  [{'name': 'clsA', 'RegulonDB ID': 'ECK12000155...
# 2  [{'name': 'rph-pyrE attenuator terminator', 'R...
# 3  [{'name': 'rpoC', 'RegulonDB ID': 'ECK12000088...
# 4  [{'name': 'hfq', 'RegulonDB ID': 'ECK120000431...
#
#                                genetic feature links  \
# 0                 {'ECK120000625': ['ECK120000625']}
# 1                 {'ECK120001556': ['ECK120001556']}
# 2  {'ECK120000854': ['ECK120000854'], 'ECK1200007...
# 3                 {'ECK120000886': ['ECK120000886']}
# 4                 {'ECK120000431': ['ECK120000431']}
#
#                                              operons  \
# 0  [{'name': 'nagBAC-umpH', 'RegulonDB ID': 'ECK1...
# 1  [{'name': 'clsA-yciU', 'RegulonDB ID': 'ECK125...
# 2  [{'name': 'rph-pyrE', 'RegulonDB ID': 'ECK1200...
# 3  [{'name': 'rplKAJL-rpoBC', 'RegulonDB ID': 'EC...
# 4  [{'name': 'yjeF-tsaE-amiB-mutL-miaA-hfq-hflXKC...
#
#                                         operon links  \
# 0                 {'ECK125162049': ['ECK120000625']}
# 1                 {'ECK125147415': ['ECK120001556']}
# 2  {'ECK120014627': ['ECK120000854', 'ECK12000079...
# 3                 {'ECK120016992': ['ECK120000886']}
# 4                 {'ECK125147410': ['ECK120000431']}
#
#                                           regulators  \
# 0  [{'name': 'PhoP', 'significantly associated co...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'name': 'CRP', 'significantly associated con...
#
#                                      regulator links  \
# 0  {'PhoP': ['ECK125162049'], 'CRP': ['ECK1251620...
# 1                                                 {}
# 2                                                 {}
# 3                                                 {}
# 4                          {'CRP': ['ECK125147410']}
#
#                                             pathways  \
# 0  [{'name': 'Galactose metabolism', 'significant...
# 1                                                 []
# 2  [{'name': 'Pyrimidine metabolism', 'significan...
# 3  [{'name': 'Purine metabolism', 'significantly ...
# 4                                                 []
#
#                                        pathway links  \
# 0  {'Galactose metabolism': ['ECK125162049'], 'Am...
# 1                                                 {}
# 2  {'Pyrimidine metabolism': ['ECK120014627'], 'D...
# 3  {'Purine metabolism': ['ECK120016992'], 'Pyrim...
# 4                                                 {}
#
#                                                 COGs  \
# 0  [{'name': 'Carbohydrate transport and metaboli...
# 1       [{'name': 'Lipid transport and metabolism'}]
# 2  [{'name': 'Nucleotide transport and metabolism'}]
# 3                        [{'name': 'Transcription'}]
# 4       [{'name': 'Signal transduction mechanisms'}]
#
#                                            COG links temperature  \
# 0  {'Carbohydrate transport and metabolism': ['EC...  42 celsius
# 1  {'Lipid transport and metabolism': ['ECK125147...  42 celsius
# 2  {'Nucleotide transport and metabolism': ['ECK1...  42 celsius
# 3                {'Transcription': ['ECK120016992']}  42 celsius
# 4  {'Signal transduction mechanisms': ['ECK125147...  42 celsius
#
#   carbon-source                   supplement strain-description taxonomy-id  \
# 0    glucose(4)  NaCl(0.5g/L) trace elements                 WT      511145
# 1    glucose(4)  NaCl(0.5g/L) trace elements                 WT      511145
# 2    glucose(4)  NaCl(0.5g/L) trace elements                 WT      511145
# 3    glucose(4)  NaCl(0.5g/L) trace elements                 WT      511145
# 4    glucose(4)  NaCl(0.5g/L) trace elements                 WT      511145
#
#   base-media nitrogen-source      phosphorous-source sulfur-source  \
# 0         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)
# 1         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)
# 2         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)
# 3         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)
# 4         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)
#
#   calcium-source
# 0     CaCl2(0.1)
# 1     CaCl2(0.1)
# 2     CaCl2(0.1)
# 3     CaCl2(0.1)
# 4     CaCl2(0.1)

# %%
op_df = pd.DataFrame()
for _, m in all_muts_df.iterrows():
    for op in m["operons"]:
        if op["name"] == "pykF":
            op_df = op_df.append(m)
            break
op_df.head()
# Out:
#                                              COG links  \
# 6    {'Carbohydrate transport and metabolism': ['EC...
# 13   {'Carbohydrate transport and metabolism': ['EC...
# 22   {'Carbohydrate transport and metabolism': ['EC...
# 36   {'Carbohydrate transport and metabolism': ['EC...
# 170  {'Carbohydrate transport and metabolism': ['EC...
#
#                                                   COGs  \
# 6    [{'name': 'Carbohydrate transport and metaboli...
# 13   [{'name': 'Carbohydrate transport and metaboli...
# 22   [{'name': 'Carbohydrate transport and metaboli...
# 36   [{'name': 'Carbohydrate transport and metaboli...
# 170  [{'name': 'Carbohydrate transport and metaboli...
#
#                     Details  \
# 6           K286* (AAA→TAA)
# 13          K286* (AAA→TAA)
# 22          K286* (AAA→TAA)
# 36          T278S (ACC→TCC)
# 170  intergenic (‑288/‑269)
#
#                                        EC number links  \
# 6    {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
# 13   {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
# 22   {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
# 36   {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
# 170  {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
#
#                                             EC numbers Mutation Type  \
# 6    [{'name': '2.7.1.40', 'significantly associate...           SNP
# 13   [{'name': '2.7.1.40', 'significantly associate...           SNP
# 22   [{'name': '2.7.1.40', 'significantly associate...           SNP
# 36   [{'name': '2.7.1.40', 'significantly associate...           SNP
# 170  [{'name': '2.7.1.40', 'significantly associate...           DEL
#
#       Position RBS Reference Seq Sequence Change TFBS   ale  \
# 6    1756553.0  {}           NaN             A→T   {}   4.0
# 13   1756553.0  {}           NaN             A→T   {}   5.0
# 22   1756553.0  {}           NaN             A→T   {}   7.0
# 36   1756529.0  {}           NaN             A→T   {}  10.0
# 170  1755429.0  {}     NC_000913          (T)5→4   {}  10.0
#
#     attenuator terminator base-media calcium-source carbon-source  coding  \
# 6                      {}         M9     CaCl2(0.1)    glucose(4)     1.0
# 13                     {}         M9     CaCl2(0.1)    glucose(4)     1.0
# 22                     {}         M9     CaCl2(0.1)    glucose(4)     1.0
# 36                     {}         M9     CaCl2(0.1)    glucose(4)     1.0
# 170                    {}         M9     CaCl2(0.1)    glucose(4)     0.0
#
#      exp exp ALE  flask gene RegulonDB ID  genetic  \
# 6    42C   42C 4  161.0    {ECK120000795}      1.0
# 13   42C   42C 5  125.0    {ECK120000795}      1.0
# 22   42C   42C 7  135.0    {ECK120000795}      1.0
# 36   42C  42C 10  153.0    {ECK120000795}      1.0
# 170  GLU  GLU 10  320.0                {}      0.0
#
#                                genetic feature links  \
# 6                 {'ECK120000795': ['ECK120000795']}
# 13                {'ECK120000795': ['ECK120000795']}
# 22                {'ECK120000795': ['ECK120000795']}
# 36                {'ECK120000795': ['ECK120000795']}
# 170  {'ECK120003492/ECK120000795': ['ECK120010529']}
#
#                                       genetic features  \
# 6    [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 13   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 22   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 36   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 170  [{'RegulonDB ID': 'ECK120003492/ECK120000795',...
#
#                                       genomic features imodulon links  \
# 6    [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...             {}
# 13   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...             {}
# 22   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...             {}
# 36   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...             {}
# 170  [{'name': 'pykFp', 'RegulonDB ID': 'ECK1200105...             {}
#
#     imodulons index  isolate mutation target annotation nitrogen-source  \
# 6          []    88      1.0                       pykF        NH4Cl(1)
# 13         []    95      1.0                       pykF        NH4Cl(1)
# 22         []   145      1.0                       pykF        NH4Cl(1)
# 36         []    17      1.0                       pykF        NH4Cl(1)
# 170        []  8222      1.0                  ydhZ/pykF        NH4Cl(1)
#
#                                         operon links  \
# 6                 {'ECK120014561': ['ECK120000795']}
# 13                {'ECK120014561': ['ECK120000795']}
# 22                {'ECK120014561': ['ECK120000795']}
# 36                {'ECK120014561': ['ECK120000795']}
# 170  {'ECK120014561': ['ECK120003492/ECK120000795']}
#
#                                                operons  oriC  \
# 6    [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
# 13   [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
# 22   [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
# 36   [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
# 170  [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
#
#                                          pathway links  \
# 6    {'Glycolysis / Gluconeogenesis': ['ECK12001456...
# 13   {'Glycolysis / Gluconeogenesis': ['ECK12001456...
# 22   {'Glycolysis / Gluconeogenesis': ['ECK12001456...
# 36   {'Glycolysis / Gluconeogenesis': ['ECK12001456...
# 170  {'Glycolysis / Gluconeogenesis': ['ECK12001456...
#
#                                               pathways  \
# 6    [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
# 13   [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
# 22   [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
# 36   [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
# 170  [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
#
#          phosphorous-source  presence  \
# 6    KH2PO4(3) Na2HPO4(6.8)       1.0
# 13   KH2PO4(3) Na2HPO4(6.8)       1.0
# 22   KH2PO4(3) Na2HPO4(6.8)       1.0
# 36   KH2PO4(3) Na2HPO4(6.8)       1.0
# 170  KH2PO4(3) Na2HPO4(6.8)       1.0
#
#                                          product links  \
# 6    {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
# 13   {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
# 22   {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
# 36   {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
# 170  {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
#
#                                               products        promoter  \
# 6    [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...              {}
# 13   [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...              {}
# 22   [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...              {}
# 36   [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...              {}
# 170  [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...  {ECK120010529}
#
#      pseudogene               range            regulator links  \
# 6           0.0  (1756553, 1756553)  {'Cra': ['ECK120014561']}
# 13          0.0  (1756553, 1756553)  {'Cra': ['ECK120014561']}
# 22          0.0  (1756553, 1756553)  {'Cra': ['ECK120014561']}
# 36          0.0  (1756529, 1756529)  {'Cra': ['ECK120014561']}
# 170         0.0  (1755429, 1755429)  {'Cra': ['ECK120014561']}
#
#                                             regulators      sample  \
# 6    [{'name': 'Cra', 'significantly associated con...   4 161 1 1
# 13   [{'name': 'Cra', 'significantly associated con...   5 125 1 1
# 22   [{'name': 'Cra', 'significantly associated con...   7 135 1 1
# 36   [{'name': 'Cra', 'significantly associated con...  10 153 1 1
# 170  [{'name': 'Cra', 'significantly associated con...  10 320 1 1
#
#     sample type strain-description sulfur-source                   supplement  \
# 6         clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
# 13        clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
# 22        clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
# 36        clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
# 170       clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
#
#     taxonomy-id  tech_rep temperature terminator
# 6        511145       1.0  42 celsius         {}
# 13       511145       1.0  42 celsius         {}
# 22       511145       1.0  42 celsius         {}
# 36       511145       1.0  42 celsius         {}
# 170      511145       1.0  37 celsius         {}

# %%
def get_sample_name(exp_name, ale, flask, isolate, tech_rep):
    sample_name = exp_name + " " + str(int(ale)) + " " + str(int(flask)) + " " + str(int(isolate)) + " " + str(int(tech_rep))
    return sample_name


op_df["sample"] = op_df.apply(lambda r: get_sample_name(r.exp, r.ale, r.flask, r.isolate, r.tech_rep), axis=1)
op_df.head()
# Out:
#                                              COG links  \
# 6    {'Carbohydrate transport and metabolism': ['EC...
# 13   {'Carbohydrate transport and metabolism': ['EC...
# 22   {'Carbohydrate transport and metabolism': ['EC...
# 36   {'Carbohydrate transport and metabolism': ['EC...
# 170  {'Carbohydrate transport and metabolism': ['EC...
#
#                                                   COGs  \
# 6    [{'name': 'Carbohydrate transport and metaboli...
# 13   [{'name': 'Carbohydrate transport and metaboli...
# 22   [{'name': 'Carbohydrate transport and metaboli...
# 36   [{'name': 'Carbohydrate transport and metaboli...
# 170  [{'name': 'Carbohydrate transport and metaboli...
#
#                     Details  \
# 6           K286* (AAA→TAA)
# 13          K286* (AAA→TAA)
# 22          K286* (AAA→TAA)
# 36          T278S (ACC→TCC)
# 170  intergenic (‑288/‑269)
#
#                                        EC number links  \
# 6    {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
# 13   {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
# 22   {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
# 36   {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
# 170  {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
#
#                                             EC numbers Mutation Type  \
# 6    [{'name': '2.7.1.40', 'significantly associate...           SNP
# 13   [{'name': '2.7.1.40', 'significantly associate...           SNP
# 22   [{'name': '2.7.1.40', 'significantly associate...           SNP
# 36   [{'name': '2.7.1.40', 'significantly associate...           SNP
# 170  [{'name': '2.7.1.40', 'significantly associate...           DEL
#
#       Position RBS Reference Seq Sequence Change TFBS   ale  \
# 6    1756553.0  {}           NaN             A→T   {}   4.0
# 13   1756553.0  {}           NaN             A→T   {}   5.0
# 22   1756553.0  {}           NaN             A→T   {}   7.0
# 36   1756529.0  {}           NaN             A→T   {}  10.0
# 170  1755429.0  {}     NC_000913          (T)5→4   {}  10.0
#
#     attenuator terminator base-media calcium-source carbon-source  coding  \
# 6                      {}         M9     CaCl2(0.1)    glucose(4)     1.0
# 13                     {}         M9     CaCl2(0.1)    glucose(4)     1.0
# 22                     {}         M9     CaCl2(0.1)    glucose(4)     1.0
# 36                     {}         M9     CaCl2(0.1)    glucose(4)     1.0
# 170                    {}         M9     CaCl2(0.1)    glucose(4)     0.0
#
#      exp exp ALE  flask gene RegulonDB ID  genetic  \
# 6    42C   42C 4  161.0    {ECK120000795}      1.0
# 13   42C   42C 5  125.0    {ECK120000795}      1.0
# 22   42C   42C 7  135.0    {ECK120000795}      1.0
# 36   42C  42C 10  153.0    {ECK120000795}      1.0
# 170  GLU  GLU 10  320.0                {}      0.0
#
#                                genetic feature links  \
# 6                 {'ECK120000795': ['ECK120000795']}
# 13                {'ECK120000795': ['ECK120000795']}
# 22                {'ECK120000795': ['ECK120000795']}
# 36                {'ECK120000795': ['ECK120000795']}
# 170  {'ECK120003492/ECK120000795': ['ECK120010529']}
#
#                                       genetic features  \
# 6    [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 13   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 22   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 36   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 170  [{'RegulonDB ID': 'ECK120003492/ECK120000795',...
#
#                                       genomic features imodulon links  \
# 6    [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...             {}
# 13   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...             {}
# 22   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...             {}
# 36   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...             {}
# 170  [{'name': 'pykFp', 'RegulonDB ID': 'ECK1200105...             {}
#
#     imodulons index  isolate mutation target annotation nitrogen-source  \
# 6          []    88      1.0                       pykF        NH4Cl(1)
# 13         []    95      1.0                       pykF        NH4Cl(1)
# 22         []   145      1.0                       pykF        NH4Cl(1)
# 36         []    17      1.0                       pykF        NH4Cl(1)
# 170        []  8222      1.0                  ydhZ/pykF        NH4Cl(1)
#
#                                         operon links  \
# 6                 {'ECK120014561': ['ECK120000795']}
# 13                {'ECK120014561': ['ECK120000795']}
# 22                {'ECK120014561': ['ECK120000795']}
# 36                {'ECK120014561': ['ECK120000795']}
# 170  {'ECK120014561': ['ECK120003492/ECK120000795']}
#
#                                                operons  oriC  \
# 6    [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
# 13   [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
# 22   [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
# 36   [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
# 170  [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
#
#                                          pathway links  \
# 6    {'Glycolysis / Gluconeogenesis': ['ECK12001456...
# 13   {'Glycolysis / Gluconeogenesis': ['ECK12001456...
# 22   {'Glycolysis / Gluconeogenesis': ['ECK12001456...
# 36   {'Glycolysis / Gluconeogenesis': ['ECK12001456...
# 170  {'Glycolysis / Gluconeogenesis': ['ECK12001456...
#
#                                               pathways  \
# 6    [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
# 13   [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
# 22   [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
# 36   [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
# 170  [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
#
#          phosphorous-source  presence  \
# 6    KH2PO4(3) Na2HPO4(6.8)       1.0
# 13   KH2PO4(3) Na2HPO4(6.8)       1.0
# 22   KH2PO4(3) Na2HPO4(6.8)       1.0
# 36   KH2PO4(3) Na2HPO4(6.8)       1.0
# 170  KH2PO4(3) Na2HPO4(6.8)       1.0
#
#                                          product links  \
# 6    {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
# 13   {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
# 22   {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
# 36   {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
# 170  {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
#
#                                               products        promoter  \
# 6    [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...              {}
# 13   [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...              {}
# 22   [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...              {}
# 36   [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...              {}
# 170  [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...  {ECK120010529}
#
#      pseudogene               range            regulator links  \
# 6           0.0  (1756553, 1756553)  {'Cra': ['ECK120014561']}
# 13          0.0  (1756553, 1756553)  {'Cra': ['ECK120014561']}
# 22          0.0  (1756553, 1756553)  {'Cra': ['ECK120014561']}
# 36          0.0  (1756529, 1756529)  {'Cra': ['ECK120014561']}
# 170         0.0  (1755429, 1755429)  {'Cra': ['ECK120014561']}
#
#                                             regulators          sample  \
# 6    [{'name': 'Cra', 'significantly associated con...   42C 4 161 1 1
# 13   [{'name': 'Cra', 'significantly associated con...   42C 5 125 1 1
# 22   [{'name': 'Cra', 'significantly associated con...   42C 7 135 1 1
# 36   [{'name': 'Cra', 'significantly associated con...  42C 10 153 1 1
# 170  [{'name': 'Cra', 'significantly associated con...  GLU 10 320 1 1
#
#     sample type strain-description sulfur-source                   supplement  \
# 6         clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
# 13        clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
# 22        clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
# 36        clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
# 170       clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
#
#     taxonomy-id  tech_rep temperature terminator
# 6        511145       1.0  42 celsius         {}
# 13       511145       1.0  42 celsius         {}
# 22       511145       1.0  42 celsius         {}
# 36       511145       1.0  42 celsius         {}
# 170      511145       1.0  37 celsius         {}

# %%
op_df["Mutation Type"].unique()
# Out:
# array(['SNP', 'DEL', 'INS', 'MOB'], dtype=object)

# %%
feat_set = set()
for _, m in op_df.iterrows():
    for f in m["genomic features"]:
        feat_set.add(f["name"])
mat = pd.DataFrame(columns=op_df["sample"].unique(), index=feat_set)
mat = mat.fillna('')

for _, m in op_df.iterrows():
    for f in m["genomic features"]:
        curr_mut_type = mat.at[f["name"], m["sample"]]
        if curr_mut_type != m["Mutation Type"]:  # oncoprint doesn't double-count mutation types within the same feature+sample (it might; need to test, but not currently needed), therefore explicitely removing to remember this quirk
            if curr_mut_type != '':
                curr_mut_type += ';'
            new_mut_type = m["Mutation Type"]
            curr_mut_type += new_mut_type
            mat.at[f["name"], m["sample"]] = curr_mut_type

mat.to_csv("./pykF_op_oncoprint_mat_genes.csv")

mat
# Out:
#           42C 4 161 1 1 42C 5 125 1 1 42C 7 135 1 1 42C 10 153 1 1  \
# pykFp
# pykF                SNP           SNP           SNP            SNP
# fumD/pykF
#
#           GLU 10 320 1 1 SER 3 50 1 1 SSW_GLU_AC 7 90 0 3 SSW_GLU_AC 8 91 0 2  \
# pykFp                DEL
# pykF                              SNP                 INS                 SNP
# fumD/pykF
#
#           TOL_hexanoic_acid 2 50 1 1 TOL_isobutyric_acid 1 50 1 1  \
# pykFp
# pykF                             SNP                          MOB
# fumD/pykF
#
#           TOL_isobutyric_acid 1 50 2 1 TOL_isobutyric_acid 2 50 1 1  \
# pykFp
# pykF                               SNP
# fumD/pykF                                                       MOB
#
#           TOL_isobutyric_acid 3 50 1 1 TOL_isobutyric_acid 3 50 2 1  \
# pykFp
# pykF                               SNP                          MOB
# fumD/pykF
#
#           TOL_isobutyric_acid 4 50 1 1 TOL_isobutyric_acid 5 50 1 1  \
# pykFp
# pykF                               INS                          SNP
# fumD/pykF
#
#           TOL_isobutyric_acid 6 50 1 1 TOL_isobutyric_acid 7 50 1 1  \
# pykFp
# pykF                               INS                          SNP
# fumD/pykF
#
#           TOL_isobutyric_acid 8 50 1 1 TOL_putrescine 4 50 1 1  \
# pykFp
# pykF                               INS                     SNP
# fumD/pykF
#
#           pyocyanin_supplemented_medium 2 19 2 1  \
# pykFp
# pykF                                         SNP
# fumD/pykF
#
#           pyocyanin_supplemented_medium 3 19 3 1 tpi 14 89 0 1 tpi 16 88 0 1  \
# pykFp
# pykF                                         SNP           MOB           SNP
# fumD/pykF
#
#           tpiHSA 3 71 1 1 tpiHSA 8 29 1 1 tpiHSA 8 34 1 1 tpiHSA 8 34 2 1  \
# pykFp
# pykF                  SNP             SNP             SNP             SNP
# fumD/pykF
#
#           tpiHSA 10 76 1 1 tpiHSA 10 104 1 1 tpiPAE 15 36 1 1  \
# pykFp
# pykF                                     SNP              DEL
# fumD/pykF              SNP
#
#           tpiPAE 16 95 1 1 tpiPAE 16 36 2 1 tpiPAE 24 31 1 1
# pykFp
# pykF                   SNP              SNP              DEL
# fumD/pykF

# %%
op_df.exp.unique()
# Out:
# array(['42C', 'GLU', 'SER', 'SSW_GLU_AC', 'TOL_hexanoic_acid',
#        'TOL_isobutyric_acid', 'TOL_putrescine',
#        'pyocyanin_supplemented_medium', 'tpi', 'tpiHSA', 'tpiPAE'],
#       dtype=object)

# %%
exp_id_d = {
    "SER": "SER",
    "42C": "42C",
    "GLU": "GLU",
    "SSW_GLU_AC": "SSW_GLU_AC",
    "SSW_GLU_XYL": "SSW_GLU_XYL",
    'TOL_hexanoic_acid': "TOL_hexanoic_acid",
    'TOL_isobutyric_acid': "TOL_isobutyric_acid",
    'TOL_putrescine': "TOL_putrescine",
    "tpi": "tpiAKO",
    "tpiHSA": "tpiHSA",
    "tpiPAE": "tpiPAE",
    "wt": "gentamycin",
    "pyocyanin_supplemented_medium": "pyocyanin",
}


op_df["exp id"] = op_df["exp"].apply(lambda exp_name: exp_id_d[exp_name])
op_df.head()
# Out:
#                                              COG links  \
# 6    {'Carbohydrate transport and metabolism': ['EC...
# 13   {'Carbohydrate transport and metabolism': ['EC...
# 22   {'Carbohydrate transport and metabolism': ['EC...
# 36   {'Carbohydrate transport and metabolism': ['EC...
# 170  {'Carbohydrate transport and metabolism': ['EC...
#
#                                                   COGs  \
# 6    [{'name': 'Carbohydrate transport and metaboli...
# 13   [{'name': 'Carbohydrate transport and metaboli...
# 22   [{'name': 'Carbohydrate transport and metaboli...
# 36   [{'name': 'Carbohydrate transport and metaboli...
# 170  [{'name': 'Carbohydrate transport and metaboli...
#
#                     Details  \
# 6           K286* (AAA→TAA)
# 13          K286* (AAA→TAA)
# 22          K286* (AAA→TAA)
# 36          T278S (ACC→TCC)
# 170  intergenic (‑288/‑269)
#
#                                        EC number links  \
# 6    {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
# 13   {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
# 22   {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
# 36   {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
# 170  {'2.7.1.40': ['ECK120014561', 'ECK120014561', ...
#
#                                             EC numbers Mutation Type  \
# 6    [{'name': '2.7.1.40', 'significantly associate...           SNP
# 13   [{'name': '2.7.1.40', 'significantly associate...           SNP
# 22   [{'name': '2.7.1.40', 'significantly associate...           SNP
# 36   [{'name': '2.7.1.40', 'significantly associate...           SNP
# 170  [{'name': '2.7.1.40', 'significantly associate...           DEL
#
#       Position RBS Reference Seq Sequence Change TFBS   ale  \
# 6    1756553.0  {}           NaN             A→T   {}   4.0
# 13   1756553.0  {}           NaN             A→T   {}   5.0
# 22   1756553.0  {}           NaN             A→T   {}   7.0
# 36   1756529.0  {}           NaN             A→T   {}  10.0
# 170  1755429.0  {}     NC_000913          (T)5→4   {}  10.0
#
#     attenuator terminator base-media calcium-source carbon-source  coding  \
# 6                      {}         M9     CaCl2(0.1)    glucose(4)     1.0
# 13                     {}         M9     CaCl2(0.1)    glucose(4)     1.0
# 22                     {}         M9     CaCl2(0.1)    glucose(4)     1.0
# 36                     {}         M9     CaCl2(0.1)    glucose(4)     1.0
# 170                    {}         M9     CaCl2(0.1)    glucose(4)     0.0
#
#      exp exp ALE  flask gene RegulonDB ID  genetic  \
# 6    42C   42C 4  161.0    {ECK120000795}      1.0
# 13   42C   42C 5  125.0    {ECK120000795}      1.0
# 22   42C   42C 7  135.0    {ECK120000795}      1.0
# 36   42C  42C 10  153.0    {ECK120000795}      1.0
# 170  GLU  GLU 10  320.0                {}      0.0
#
#                                genetic feature links  \
# 6                 {'ECK120000795': ['ECK120000795']}
# 13                {'ECK120000795': ['ECK120000795']}
# 22                {'ECK120000795': ['ECK120000795']}
# 36                {'ECK120000795': ['ECK120000795']}
# 170  {'ECK120003492/ECK120000795': ['ECK120010529']}
#
#                                       genetic features  \
# 6    [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 13   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 22   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 36   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...
# 170  [{'RegulonDB ID': 'ECK120003492/ECK120000795',...
#
#                                       genomic features imodulon links  \
# 6    [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...             {}
# 13   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...             {}
# 22   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...             {}
# 36   [{'name': 'pykF', 'RegulonDB ID': 'ECK12000079...             {}
# 170  [{'name': 'pykFp', 'RegulonDB ID': 'ECK1200105...             {}
#
#     imodulons index  isolate mutation target annotation nitrogen-source  \
# 6          []    88      1.0                       pykF        NH4Cl(1)
# 13         []    95      1.0                       pykF        NH4Cl(1)
# 22         []   145      1.0                       pykF        NH4Cl(1)
# 36         []    17      1.0                       pykF        NH4Cl(1)
# 170        []  8222      1.0                  ydhZ/pykF        NH4Cl(1)
#
#                                         operon links  \
# 6                 {'ECK120014561': ['ECK120000795']}
# 13                {'ECK120014561': ['ECK120000795']}
# 22                {'ECK120014561': ['ECK120000795']}
# 36                {'ECK120014561': ['ECK120000795']}
# 170  {'ECK120014561': ['ECK120003492/ECK120000795']}
#
#                                                operons  oriC  \
# 6    [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
# 13   [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
# 22   [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
# 36   [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
# 170  [{'name': 'pykF', 'RegulonDB ID': 'ECK12001456...   0.0
#
#                                          pathway links  \
# 6    {'Glycolysis / Gluconeogenesis': ['ECK12001456...
# 13   {'Glycolysis / Gluconeogenesis': ['ECK12001456...
# 22   {'Glycolysis / Gluconeogenesis': ['ECK12001456...
# 36   {'Glycolysis / Gluconeogenesis': ['ECK12001456...
# 170  {'Glycolysis / Gluconeogenesis': ['ECK12001456...
#
#                                               pathways  \
# 6    [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
# 13   [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
# 22   [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
# 36   [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
# 170  [{'name': 'Glycolysis / Gluconeogenesis', 'sig...
#
#          phosphorous-source  presence  \
# 6    KH2PO4(3) Na2HPO4(6.8)       1.0
# 13   KH2PO4(3) Na2HPO4(6.8)       1.0
# 22   KH2PO4(3) Na2HPO4(6.8)       1.0
# 36   KH2PO4(3) Na2HPO4(6.8)       1.0
# 170  KH2PO4(3) Na2HPO4(6.8)       1.0
#
#                                          product links  \
# 6    {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
# 13   {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
# 22   {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
# 36   {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
# 170  {'Pyruvate kinase (EC 2.7.1.40)': ['ECK1200145...
#
#                                               products        promoter  \
# 6    [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...              {}
# 13   [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...              {}
# 22   [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...              {}
# 36   [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...              {}
# 170  [{'name': 'Pyruvate kinase (EC 2.7.1.40)', 'si...  {ECK120010529}
#
#      pseudogene               range            regulator links  \
# 6           0.0  (1756553, 1756553)  {'Cra': ['ECK120014561']}
# 13          0.0  (1756553, 1756553)  {'Cra': ['ECK120014561']}
# 22          0.0  (1756553, 1756553)  {'Cra': ['ECK120014561']}
# 36          0.0  (1756529, 1756529)  {'Cra': ['ECK120014561']}
# 170         0.0  (1755429, 1755429)  {'Cra': ['ECK120014561']}
#
#                                             regulators          sample  \
# 6    [{'name': 'Cra', 'significantly associated con...   42C 4 161 1 1
# 13   [{'name': 'Cra', 'significantly associated con...   42C 5 125 1 1
# 22   [{'name': 'Cra', 'significantly associated con...   42C 7 135 1 1
# 36   [{'name': 'Cra', 'significantly associated con...  42C 10 153 1 1
# 170  [{'name': 'Cra', 'significantly associated con...  GLU 10 320 1 1
#
#     sample type strain-description sulfur-source                   supplement  \
# 6         clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
# 13        clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
# 22        clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
# 36        clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
# 170       clone                 WT   MgSO4(0.24)  NaCl(0.5g/L) trace elements
#
#     taxonomy-id  tech_rep temperature terminator exp id
# 6        511145       1.0  42 celsius         {}    42C
# 13       511145       1.0  42 celsius         {}    42C
# 22       511145       1.0  42 celsius         {}    42C
# 36       511145       1.0  42 celsius         {}    42C
# 170      511145       1.0  37 celsius         {}    GLU

# %%
cond_cols = {
    'base-media',
    'calcium-source',
    'carbon-source',
    'nitrogen-source',
    'phosphorous-source',
    'strain-description',
    'sulfur-source',
    'supplement',
    'temperature',
    'exp id'
}
cond_mat = pd.DataFrame(
    columns=op_df["sample"].unique(),
    index=cond_cols
)
cond_mat = cond_mat.fillna('')

for _, m in op_df.iterrows():
    for cond_col in cond_cols:
        cond_mat.at[cond_col, m['sample']] = m[cond_col]
        
# Serine's default supplement annotation is too large.
cond_mat = cond_mat.T
cond_mat["supplement"] = cond_mat["supplement"].apply(lambda x: "glycine(2mM) & L-serine" if x == "glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)" else x)
cond_mat["supplement"] = cond_mat["supplement"].apply(lambda x: "NaCl(0.5) trace elements" if x == "NaCl(0.5g/L) trace elements" else x)
cond_mat["temperature"] = cond_mat["temperature"].apply(lambda x: x.replace("celsius", "Celsius"))
cond_mat = cond_mat.T
cond_mat.to_csv("./pykF_op_oncoprint_mat_conditions.csv")
cond_mat
# Out:
#                                42C 4 161 1 1             42C 5 125 1 1  \
# supplement          NaCl(0.5) trace elements  NaCl(0.5) trace elements
# phosphorous-source    KH2PO4(3) Na2HPO4(6.8)    KH2PO4(3) Na2HPO4(6.8)
# base-media                                M9                        M9
# temperature                       42 Celsius                42 Celsius
# exp id                                   42C                       42C
# carbon-source                     glucose(4)                glucose(4)
# strain-description                        WT                        WT
# calcium-source                    CaCl2(0.1)                CaCl2(0.1)
# nitrogen-source                     NH4Cl(1)                  NH4Cl(1)
# sulfur-source                    MgSO4(0.24)               MgSO4(0.24)
#
#                                42C 7 135 1 1            42C 10 153 1 1  \
# supplement          NaCl(0.5) trace elements  NaCl(0.5) trace elements
# phosphorous-source    KH2PO4(3) Na2HPO4(6.8)    KH2PO4(3) Na2HPO4(6.8)
# base-media                                M9                        M9
# temperature                       42 Celsius                42 Celsius
# exp id                                   42C                       42C
# carbon-source                     glucose(4)                glucose(4)
# strain-description                        WT                        WT
# calcium-source                    CaCl2(0.1)                CaCl2(0.1)
# nitrogen-source                     NH4Cl(1)                  NH4Cl(1)
# sulfur-source                    MgSO4(0.24)               MgSO4(0.24)
#
#                               GLU 10 320 1 1             SER 3 50 1 1  \
# supplement          NaCl(0.5) trace elements  glycine(2mM) & L-serine
# phosphorous-source    KH2PO4(3) Na2HPO4(6.8)   KH2PO4(3) Na2HPO4(6.8)
# base-media                                M9                       M9
# temperature                       37 Celsius               37 Celsius
# exp id                                   GLU                      SER
# carbon-source                     glucose(4)               glucose(2)
# strain-description                        WT  ΔsdaA ΔsdaB ΔtdcG ΔglyA
# calcium-source                    CaCl2(0.1)               CaCl2(0.1)
# nitrogen-source                     NH4Cl(1)                 NH4Cl(1)
# sulfur-source                    MgSO4(0.24)              MgSO4(0.24)
#
#                          SSW_GLU_AC 7 90 0 3       SSW_GLU_AC 8 91 0 2  \
# supplement          NaCl(0.5) trace elements  NaCl(0.5) trace elements
# phosphorous-source    KH2PO4(3) Na2HPO4(6.8)    KH2PO4(3) Na2HPO4(6.8)
# base-media                                M9                        M9
# temperature                       37 Celsius                37 Celsius
# exp id                            SSW_GLU_AC                SSW_GLU_AC
# carbon-source       glucose(4) or acetate(4)  glucose(4) or acetate(4)
# strain-description                        WT                        WT
# calcium-source                    CaCl2(0.1)                CaCl2(0.1)
# nitrogen-source                     NH4Cl(1)                  NH4Cl(1)
# sulfur-source                    MgSO4(0.24)               MgSO4(0.24)
#
#                    TOL_hexanoic_acid 2 50 1 1 TOL_isobutyric_acid 1 50 1 1  \
# supplement                      hexanoic acid              isobutyric acid
# phosphorous-source     KH2PO4(3) Na2HPO4(6.8)       KH2PO4(3) Na2HPO4(6.8)
# base-media                                 M9                           M9
# temperature                        37 Celsius                   37 Celsius
# exp id                      TOL_hexanoic_acid          TOL_isobutyric_acid
# carbon-source                      glucose(2)                   glucose(2)
# strain-description                         WT                           WT
# calcium-source                     CaCl2(0.1)                   CaCl2(0.1)
# nitrogen-source                      NH4Cl(1)                     NH4Cl(1)
# sulfur-source                     MgSO4(0.24)                  MgSO4(0.24)
#
#                    TOL_isobutyric_acid 1 50 2 1 TOL_isobutyric_acid 2 50 1 1  \
# supplement                      isobutyric acid              isobutyric acid
# phosphorous-source       KH2PO4(3) Na2HPO4(6.8)       KH2PO4(3) Na2HPO4(6.8)
# base-media                                   M9                           M9
# temperature                          37 Celsius                   37 Celsius
# exp id                      TOL_isobutyric_acid          TOL_isobutyric_acid
# carbon-source                        glucose(2)                   glucose(2)
# strain-description                           WT                           WT
# calcium-source                       CaCl2(0.1)                   CaCl2(0.1)
# nitrogen-source                        NH4Cl(1)                     NH4Cl(1)
# sulfur-source                       MgSO4(0.24)                  MgSO4(0.24)
#
#                    TOL_isobutyric_acid 3 50 1 1 TOL_isobutyric_acid 3 50 2 1  \
# supplement                      isobutyric acid              isobutyric acid
# phosphorous-source       KH2PO4(3) Na2HPO4(6.8)       KH2PO4(3) Na2HPO4(6.8)
# base-media                                   M9                           M9
# temperature                          37 Celsius                   37 Celsius
# exp id                      TOL_isobutyric_acid          TOL_isobutyric_acid
# carbon-source                        glucose(2)                   glucose(2)
# strain-description                           WT                           WT
# calcium-source                       CaCl2(0.1)                   CaCl2(0.1)
# nitrogen-source                        NH4Cl(1)                     NH4Cl(1)
# sulfur-source                       MgSO4(0.24)                  MgSO4(0.24)
#
#                    TOL_isobutyric_acid 4 50 1 1 TOL_isobutyric_acid 5 50 1 1  \
# supplement                      isobutyric acid              isobutyric acid
# phosphorous-source       KH2PO4(3) Na2HPO4(6.8)       KH2PO4(3) Na2HPO4(6.8)
# base-media                                   M9                           M9
# temperature                          37 Celsius                   37 Celsius
# exp id                      TOL_isobutyric_acid          TOL_isobutyric_acid
# carbon-source                        glucose(2)                   glucose(2)
# strain-description                           WT                           WT
# calcium-source                       CaCl2(0.1)                   CaCl2(0.1)
# nitrogen-source                        NH4Cl(1)                     NH4Cl(1)
# sulfur-source                       MgSO4(0.24)                  MgSO4(0.24)
#
#                    TOL_isobutyric_acid 6 50 1 1 TOL_isobutyric_acid 7 50 1 1  \
# supplement                      isobutyric acid              isobutyric acid
# phosphorous-source       KH2PO4(3) Na2HPO4(6.8)       KH2PO4(3) Na2HPO4(6.8)
# base-media                                   M9                           M9
# temperature                          37 Celsius                   37 Celsius
# exp id                      TOL_isobutyric_acid          TOL_isobutyric_acid
# carbon-source                        glucose(2)                   glucose(2)
# strain-description                           WT                           WT
# calcium-source                       CaCl2(0.1)                   CaCl2(0.1)
# nitrogen-source                        NH4Cl(1)                     NH4Cl(1)
# sulfur-source                       MgSO4(0.24)                  MgSO4(0.24)
#
#                    TOL_isobutyric_acid 8 50 1 1 TOL_putrescine 4 50 1 1  \
# supplement                      isobutyric acid              putrescine
# phosphorous-source       KH2PO4(3) Na2HPO4(6.8)  KH2PO4(3) Na2HPO4(6.8)
# base-media                                   M9                      M9
# temperature                          37 Celsius              37 Celsius
# exp id                      TOL_isobutyric_acid          TOL_putrescine
# carbon-source                        glucose(2)              glucose(2)
# strain-description                           WT                      WT
# calcium-source                       CaCl2(0.1)              CaCl2(0.1)
# nitrogen-source                        NH4Cl(1)                NH4Cl(1)
# sulfur-source                       MgSO4(0.24)             MgSO4(0.24)
#
#                    pyocyanin_supplemented_medium 2 19 2 1  \
# supplement                            C13H10N2O(0.168184)
# phosphorous-source                           KH2PO4(13.6)
# base-media                                            M63
# temperature                                    37 Celsius
# exp id                                          pyocyanin
# carbon-source                                  glucose(3)
# strain-description                                     WT
# calcium-source                                       none
# nitrogen-source                              (NH4)2SO4(2)
# sulfur-source                    (NH4)2SO4(2) MgSO4(0.12)
#
#                    pyocyanin_supplemented_medium 3 19 3 1  \
# supplement                            C13H10N2O(0.168184)
# phosphorous-source                           KH2PO4(13.6)
# base-media                                            M63
# temperature                                    37 Celsius
# exp id                                          pyocyanin
# carbon-source                                  glucose(3)
# strain-description                                     WT
# calcium-source                                       none
# nitrogen-source                              (NH4)2SO4(2)
# sulfur-source                    (NH4)2SO4(2) MgSO4(0.12)
#
#                                    tpi 14 89 0 1  \
# supplement              NaCl(0.5) trace elements
# phosphorous-source        KH2PO4(3) Na2HPO4(6.8)
# base-media                                    M9
# temperature                           37 Celsius
# exp id                                    tpiAKO
# carbon-source                         glucose(4)
# strain-description  ΔtpiA glucose M9 pre-evolved
# calcium-source                        CaCl2(0.1)
# nitrogen-source                         NH4Cl(1)
# sulfur-source                        MgSO4(0.24)
#
#                                    tpi 16 88 0 1           tpiHSA 3 71 1 1  \
# supplement              NaCl(0.5) trace elements  NaCl(0.5) trace elements
# phosphorous-source        KH2PO4(3) Na2HPO4(6.8)    KH2PO4(3) Na2HPO4(6.8)
# base-media                                    M9                        M9
# temperature                           37 Celsius                37 Celsius
# exp id                                    tpiAKO                    tpiHSA
# carbon-source                         glucose(4)                glucose(4)
# strain-description  ΔtpiA glucose M9 pre-evolved            H. sapien tpiA
# calcium-source                        CaCl2(0.1)                CaCl2(0.1)
# nitrogen-source                         NH4Cl(1)                  NH4Cl(1)
# sulfur-source                        MgSO4(0.24)               MgSO4(0.24)
#
#                              tpiHSA 8 29 1 1           tpiHSA 8 34 1 1  \
# supplement          NaCl(0.5) trace elements  NaCl(0.5) trace elements
# phosphorous-source    KH2PO4(3) Na2HPO4(6.8)    KH2PO4(3) Na2HPO4(6.8)
# base-media                                M9                        M9
# temperature                       37 Celsius                37 Celsius
# exp id                                tpiHSA                    tpiHSA
# carbon-source                     glucose(4)                glucose(4)
# strain-description            H. sapien tpiA            H. sapien tpiA
# calcium-source                    CaCl2(0.1)                CaCl2(0.1)
# nitrogen-source                     NH4Cl(1)                  NH4Cl(1)
# sulfur-source                    MgSO4(0.24)               MgSO4(0.24)
#
#                              tpiHSA 8 34 2 1          tpiHSA 10 76 1 1  \
# supplement          NaCl(0.5) trace elements  NaCl(0.5) trace elements
# phosphorous-source    KH2PO4(3) Na2HPO4(6.8)    KH2PO4(3) Na2HPO4(6.8)
# base-media                                M9                        M9
# temperature                       37 Celsius                37 Celsius
# exp id                                tpiHSA                    tpiHSA
# carbon-source                     glucose(4)                glucose(4)
# strain-description            H. sapien tpiA            H. sapien tpiA
# calcium-source                    CaCl2(0.1)                CaCl2(0.1)
# nitrogen-source                     NH4Cl(1)                  NH4Cl(1)
# sulfur-source                    MgSO4(0.24)               MgSO4(0.24)
#
#                            tpiHSA 10 104 1 1          tpiPAE 15 36 1 1  \
# supplement          NaCl(0.5) trace elements  NaCl(0.5) trace elements
# phosphorous-source    KH2PO4(3) Na2HPO4(6.8)    KH2PO4(3) Na2HPO4(6.8)
# base-media                                M9                        M9
# temperature                       37 Celsius                37 Celsius
# exp id                                tpiHSA                    tpiPAE
# carbon-source                     glucose(4)                glucose(4)
# strain-description            H. sapien tpiA        P. aerophilum tpiA
# calcium-source                    CaCl2(0.1)                CaCl2(0.1)
# nitrogen-source                     NH4Cl(1)                  NH4Cl(1)
# sulfur-source                    MgSO4(0.24)               MgSO4(0.24)
#
#                             tpiPAE 16 95 1 1          tpiPAE 16 36 2 1  \
# supplement          NaCl(0.5) trace elements  NaCl(0.5) trace elements
# phosphorous-source    KH2PO4(3) Na2HPO4(6.8)    KH2PO4(3) Na2HPO4(6.8)
# base-media                                M9                        M9
# temperature                       37 Celsius                37 Celsius
# exp id                                tpiPAE                    tpiPAE
# carbon-source                     glucose(4)                glucose(4)
# strain-description        P. aerophilum tpiA        P. aerophilum tpiA
# calcium-source                    CaCl2(0.1)                CaCl2(0.1)
# nitrogen-source                     NH4Cl(1)                  NH4Cl(1)
# sulfur-source                    MgSO4(0.24)               MgSO4(0.24)
#
#                             tpiPAE 24 31 1 1
# supplement          NaCl(0.5) trace elements
# phosphorous-source    KH2PO4(3) Na2HPO4(6.8)
# base-media                                M9
# temperature                       37 Celsius
# exp id                                tpiPAE
# carbon-source                     glucose(4)
# strain-description        P. aerophilum tpiA
# calcium-source                    CaCl2(0.1)
# nitrogen-source                     NH4Cl(1)
# sulfur-source                    MgSO4(0.24)
