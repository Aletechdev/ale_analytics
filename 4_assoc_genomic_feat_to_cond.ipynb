# %% [markdown]
# TODO: Split the annotating of mutations with conditions and the associating of genomic features with conditions into 2 NBs.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from IPython.display import display
import os, sys, itertools, csv
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from mutil.alemutdf import get_all_sample_mut_df, get_gene_mut_count_mat, get_multi_exp_max_freq_mut_df, get_mut_type_avg_frac_across_class_df
from mutil.metadata import get_condition_val_dict, get_condition_field_val_set
from mutil.genome import get_K12_pos_from_BOP27
from mutil.params import ASSOC_ALPHA, MULTI_HYP_CORR_METHOD
pd.options.display.max_columns = 100

# %%
# starting efforts for refactoring of assoc NBs.
FEAT_ANNOT = "genomic features"

# %%
all_muts_df = pd.read_pickle("./data/2_6_df.pkl")
display(all_muts_df.shape, all_muts_df.head())
# Out:
# (3921, 38)
#   index  exp  ale  flask  isolate  tech_rep  presence  Position Mutation Type  \
# 0     9  42C    1    124        1         1       1.0    702352           DEL
# 1    10  42C    1    124        1         1       1.0   1308318           SNP
# 2    11  42C    1    124        1         1       1.0   3815859           DEL
# 3    12  42C    1    124        1         1       1.0   4187550           SNP
# 4    13  42C    1    124        1         1       1.0   4400313           SNP
#
#   Sequence Change                   Details mutation target annotation  \
# 0          Δ21 bp  coding (380‑400/1149 nt)                       nagA
# 1             G→C           R110G (CGT→GGT)                       clsA
# 2          Δ82 bp                                                  rph
# 3             C→T           A734V (GCG→GTG)                       rpoC
# 4             A→C             D9A (GAT→GCT)                        hfq
#
#   Reference Seq     sample sample type exp ALE  coding               range  \
# 0           NaN  1 124 1 1       clone   42C 1    True    (702352, 702372)
# 1           NaN  1 124 1 1       clone   42C 1    True  (1308318, 1308318)
# 2           NaN  1 124 1 1       clone   42C 1    True  (3815859, 3815940)
# 3           NaN  1 124 1 1       clone   42C 1    True  (4187550, 4187550)
# 4           NaN  1 124 1 1       clone   42C 1    True  (4400313, 4400313)
#
#   gene RegulonDB ID                                   genetic features   oriC  \
# 0    {ECK120000625}  [{'name': 'nagA', 'RegulonDB ID': 'ECK12000062...  False
# 1    {ECK120001556}  [{'name': 'clsA', 'RegulonDB ID': 'ECK12000155...  False
# 2    {ECK120000854}  [{'name': 'rph', 'RegulonDB ID': 'ECK120000854...  False
# 3    {ECK120000886}  [{'name': 'rpoC', 'RegulonDB ID': 'ECK12000088...  False
# 4    {ECK120000431}  [{'name': 'hfq', 'RegulonDB ID': 'ECK120000431...  False
#
#    pseudogene TFBS promoter RBS attenuator terminator terminator  genetic  \
# 0       False   {}       {}  {}                    {}         {}     True
# 1       False   {}       {}  {}                    {}         {}     True
# 2       False   {}       {}  {}        {ECK125144791}         {}     True
# 3       False   {}       {}  {}                    {}         {}     True
# 4       False   {}       {}  {}                    {}         {}     True
#
#                                     genomic features  \
# 0  [{'name': 'nagA', 'RegulonDB ID': 'ECK12000062...
# 1  [{'name': 'clsA', 'RegulonDB ID': 'ECK12000155...
# 2  [{'name': 'rph-pyrE attenuator terminator', 'R...
# 3  [{'name': 'rpoC', 'RegulonDB ID': 'ECK12000088...
# 4  [{'name': 'hfq', 'RegulonDB ID': 'ECK120000431...
#
#                                genetic feature links  \
# 0                 {'ECK120000625': ['ECK120000625']}
# 1                 {'ECK120001556': ['ECK120001556']}
# 2  {'ECK120000854': ['ECK120000854'], 'ECK1200007...
# 3                 {'ECK120000886': ['ECK120000886']}
# 4                 {'ECK120000431': ['ECK120000431']}
#
#                                              operons  \
# 0  [{'name': 'nagBAC-umpH', 'RegulonDB ID': 'ECK1...
# 1  [{'name': 'clsA-yciU', 'RegulonDB ID': 'ECK125...
# 2  [{'name': 'rph-pyrE', 'RegulonDB ID': 'ECK1200...
# 3  [{'name': 'rplKAJL-rpoBC', 'RegulonDB ID': 'EC...
# 4  [{'name': 'yjeF-tsaE-amiB-mutL-miaA-hfq-hflXKC...
#
#                                         operon links  \
# 0                 {'ECK125162049': ['ECK120000625']}
# 1                 {'ECK125147415': ['ECK120001556']}
# 2  {'ECK120014627': ['ECK120000854', 'ECK12000079...
# 3                 {'ECK120016992': ['ECK120000886']}
# 4                 {'ECK125147410': ['ECK120000431']}
#
#                                           regulators  \
# 0  [{'name': 'PhoP'}, {'name': 'CRP'}, {'name': '...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                  [{'name': 'CRP'}]
#
#                                      regulator links  \
# 0  {'PhoP': ['ECK125162049'], 'CRP': ['ECK1251620...
# 1                                                 {}
# 2                                                 {}
# 3                                                 {}
# 4                          {'CRP': ['ECK125147410']}
#
#                                             pathways  \
# 0  [{'name': 'Galactose metabolism'}, {'name': 'A...
# 1                                                 []
# 2  [{'name': 'Pyrimidine metabolism'}, {'name': '...
# 3  [{'name': 'Purine metabolism'}, {'name': 'Pyri...
# 4                                                 []
#
#                                        pathway links  \
# 0  {'Galactose metabolism': ['ECK125162049'], 'Am...
# 1                                                 {}
# 2  {'Pyrimidine metabolism': ['ECK120014627'], 'D...
# 3  {'Purine metabolism': ['ECK120016992'], 'Pyrim...
# 4                                                 {}
#
#                                                 COGs  \
# 0  [{'name': 'Carbohydrate transport and metaboli...
# 1       [{'name': 'Lipid transport and metabolism'}]
# 2  [{'name': 'Nucleotide transport and metabolism'}]
# 3                        [{'name': 'Transcription'}]
# 4       [{'name': 'Signal transduction mechanisms'}]
#
#                                            COG links
# 0  {'Carbohydrate transport and metabolism': ['EC...
# 1  {'Lipid transport and metabolism': ['ECK125147...
# 2  {'Nucleotide transport and metabolism': ['ECK1...
# 3                {'Transcription': ['ECK120016992']}
# 4  {'Signal transduction mechanisms': ['ECK125147...

# %%
# temporarily changing some of the contents of the mutation data since 
temp_exp_to_remove_till_reprocess = ["42C_Tenaillon", "TEE", "TEE_Ara", "LTEE", "LTEE_Ara", "delta_dnaQ"]
all_muts_df = all_muts_df[~(all_muts_df.exp.isin(temp_exp_to_remove_till_reprocess))]
all_muts_df["exp"] = all_muts_df.apply(lambda r: "gallium-nitrate" if r["exp"] == "untreated" else r["exp"], axis=1)

# %% [markdown]
# ## enrichment analysis between conditions and mutated genomic features

# %% [markdown]
# ### Get metadata

# %%
from mutil.metadata import get_all_exp_cond_d

all_exp_cond_d = get_all_exp_cond_d("./data/metadata/")
all_exp_cond_d["TOL_2,3-butanediol"] = all_exp_cond_d.pop("TOL_2 3-butanediol")  # TODO: workaround for bug of missing comma. Fix root bug
all_exp_cond_d
# Out:
# {'Iron-ALE': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'FeSO4(20uM) sodium citrate(10mM)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'application_of_ALE_to_re-optimize_growth_performance_of_genome-reduced_strain_MS56-M9-MG1655gbk': {'carbon-source': 'glucose(2)',
#   'taxonomy-id': '511145',
#   'strain-description': 'MS57',
#   'temperature': '37 celsius',
#   'base-media': 'M63',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.78)',
#   'sulfur-source': 'MgSO4(1mM)',
#   'calcium-source': 'CaCl2(0.1mM)'},
#  'pvdJ_KO_P_aeruginosa_spent_medium': {'carbon-source': 'glucose(3)',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M63',
#   'supplement': 'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'nitrogen-source': '(NH4)2SO4(2)',
#   'phosphorous-source': 'KH2PO4(13.6)',
#   'sulfur-source': '(NH4)2SO4(2) MgSO4(0.12)',
#   'calcium-source': 'none'},
#  'TOL_glutaric_acid': {'supplement': 'glutaric acid',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'MG1655-M9-NC_000913_3gb-stationary-37-D-2-deoxyribose2': {'carbon-source': 'D-2-deoxyribose',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'WT_P_aeruginosa_spent_medium': {'carbon-source': 'glucose(3)',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M63',
#   'supplement': 'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'nitrogen-source': '(NH4)2SO4(2)',
#   'phosphorous-source': 'KH2PO4(13.6)',
#   'sulfur-source': '(NH4)2SO4(2) MgSO4(0.12)',
#   'calcium-source': 'none'},
#  'TOL_hexanoic_acid': {'supplement': 'hexanoic acid',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'TOL_putrescine': {'supplement': 'putrescine',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'MG1655-M9-NC_000913_3gb-stationary-37-monomethyl_succinate2': {'carbon-source': 'monomethyl succinate',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'BOP1000_pfkA': {'taxonomy-id': '511145',
#   'strain-description': 'ΔpfkA glucose M9 evolved',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'BOP1000_acnB': {'taxonomy-id': '511145',
#   'strain-description': 'ΔacnB glucose M9 evolved',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'SSW_XYL': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'xylose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'gnd': {'taxonomy-id': '511145',
#   'strain-description': 'Δgnd glucose M9 pre-evolved',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'tpiHSA': {'taxonomy-id': '511145',
#   'strain-description': 'H. sapien tpiA',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'BOP_27_pfkA': {'taxonomy-id': '511145',
#   'strain-description': 'ΔpfkA',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'TOL_coumaric_acid': {'supplement': 'coumaric acid',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'pgi': {'taxonomy-id': '511145',
#   'strain-description': 'Δpgi glucose M9 pre-evolved',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'MG1655-blaTEM1_ceftazidime': {'supplement': 'ceftazidime',
#   'taxonomy-id': '511145',
#   'strain-description': 'bla-TEM-1',
#   'temperature': '37 celsius',
#   'base-media': 'LB',
#   'carbon-source': 'LB',
#   'nitrogen-source': 'LB',
#   'phosphorous-source': 'LB',
#   'sulfur-source': 'LB',
#   'calcium-source': 'LB'},
#  'OxidizeME_PQ3': {'carbon-source': 'glucose(4)',
#   'taxonomy-id': '511145',
#   'strain-description': 'glucose-evolved BOP1000',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'supplement': 'PQ(0.8mM)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'BOP1000_sucB': {'taxonomy-id': '511145',
#   'strain-description': 'ΔsucB glucose M9 evolved',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'pgiPAE': {'taxonomy-id': '511145',
#   'strain-description': 'P. aerophilum pgi',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'TOL_octanoic_acid': {'supplement': 'octanoic acid',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'TOL_hexamethylenediamine': {'supplement': 'hexamethylenediamine',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'pts': {'taxonomy-id': '511145',
#   'strain-description': 'ΔptsHI-crr glucose M9 pre-evolved',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'TOL_n-butanol': {'supplement': 'n-butanol',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'MG1655_chloramphenicol': {'supplement': 'chloramphenicol',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '30 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'wt': {'supplement': 'gentamycin(0.03)',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'SSW_GLU_XYL': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(4) or xylose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'GYD': {'organism': 'eco',
#   'strain-description': 'WT',
#   'base-media': 'M9',
#   'carbon-source': 'glycerol(2.5)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'antibiotic-resistance': '',
#   'illumina-kit': '300 Cycle',
#   'expertiment-details': '',
#   'taxonomy-id': '511145',
#   'temperature': '30 celsius',
#   'calcium-source': 'CaCl2(0.1)'},
#  'ILT_MG1655': {'carbon-source': 'glucose(2)',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'MG1655-pBGT_ceftazidime': {'supplement': 'ceftazidime',
#   'taxonomy-id': '511145',
#   'strain-description': 'pBGT',
#   'temperature': '37 celsius',
#   'base-media': 'LB',
#   'carbon-source': 'LB',
#   'nitrogen-source': 'LB',
#   'phosphorous-source': 'LB',
#   'sulfur-source': 'LB',
#   'calcium-source': 'LB'},
#  'TOL_adipic_acid': {'supplement': 'adipic acid',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'JCL260__isobutanol_production_host-M9-MG1655gbk': {'carbon-source': 'glucose(3)',
#   'taxonomy-id': '511145',
#   'strain-description': 'JCL260',
#   'temperature': '37 celsius',
#   'base-media': 'LB',
#   'supplement': 'isobutanol(8g/L)',
#   'nitrogen-source': 'LB',
#   'phosphorous-source': 'LB',
#   'sulfur-source': 'LB',
#   'calcium-source': 'LB'},
#  'tpi': {'taxonomy-id': '511145',
#   'strain-description': 'ΔtpiA glucose M9 pre-evolved',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'pgiVCH': {'taxonomy-id': '511145',
#   'strain-description': 'V. cholerae pgi',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'tpiKO': {'taxonomy-id': '511145',
#   'strain-description': 'ΔtpiA',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'EG_pCA24N-fucO': {'supplement': 'chloramphenicol(25)',
#   'taxonomy-id': '511145',
#   'strain-description': 'E. coli K-12 MG1655 pCA24N-fucO',
#   'temperature': '30 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'ethylene glycol(30mM)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'MG1655-pBGT_untreated': {'supplement': 'LB',
#   'taxonomy-id': '511145',
#   'strain-description': 'pBGT',
#   'temperature': '37 celsius',
#   'base-media': 'LB',
#   'carbon-source': 'LB',
#   'nitrogen-source': 'LB',
#   'phosphorous-source': 'LB',
#   'sulfur-source': 'LB',
#   'calcium-source': 'LB'},
#  'BOP_27_rpe': {'taxonomy-id': '511145',
#   'strain-description': 'Δrpe',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'SSW_GLY': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glycerol(2.5)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'PGI': {'taxonomy-id': '511145',
#   'strain-description': 'Δpgi',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'evo': {'taxonomy-id': '511145',
#   'strain-description': 'GMOS',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'pgiHSA': {'taxonomy-id': '511145',
#   'strain-description': 'H. sapien pgi',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'MG1655_ceftazidime': {'supplement': 'ceftazidime',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'LB',
#   'carbon-source': 'LB',
#   'nitrogen-source': 'LB',
#   'phosphorous-source': 'LB',
#   'sulfur-source': 'LB',
#   'calcium-source': 'LB'},
#  'MG1655-M9-NC_000913_3gb-stationary-37-m-tartrate2': {'carbon-source': 'm-tartrate',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'SSW_GLU_AC': {'strain-description': 'WT',
#   'taxonomy-id': '511145',
#   'nitrogen-source': 'NH4Cl(1)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'base-media': 'M9',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'carbon-source': 'glucose(4) or acetate(4)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'temperature': '37 celsius',
#   'calcium-source': 'CaCl2(0.1)'},
#  '42C': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '42 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'GLU': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'MG1655-blaTEM1_untreated': {'supplement': 'LB',
#   'taxonomy-id': '511145',
#   'strain-description': 'bla-TEM-1',
#   'temperature': '37 celsius',
#   'base-media': 'LB',
#   'carbon-source': 'LB',
#   'nitrogen-source': 'LB',
#   'phosphorous-source': 'LB',
#   'sulfur-source': 'LB',
#   'calcium-source': 'LB'},
#  'BOP_27_sucB': {'taxonomy-id': '511145',
#   'strain-description': 'ΔsucB',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'BOP_27_acnB': {'taxonomy-id': '511145',
#   'strain-description': 'ΔacnB',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'pyocyanin_supplemented_medium': {'carbon-source': 'glucose(3)',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M63',
#   'supplement': 'C13H10N2O(0.168184)',
#   'nitrogen-source': '(NH4)2SO4(2)',
#   'phosphorous-source': 'KH2PO4(13.6)',
#   'sulfur-source': '(NH4)2SO4(2) MgSO4(0.12)',
#   'calcium-source': 'none'},
#  'MG1655_untreated': {'supplement': 'LB',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'LB',
#   'carbon-source': 'LB',
#   'nitrogen-source': 'LB',
#   'phosphorous-source': 'LB',
#   'sulfur-source': 'LB',
#   'calcium-source': 'LB'},
#  'MG1655-M9-NC_000913_3gb-stationary-37-D-lyxose2': {'carbon-source': 'D-lyxose',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'MG1655_doxycycline': {'supplement': 'doxycycline',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '30 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'MG1655-M9-NC_000913_3gb-stationary-37-D-arabinose2': {'carbon-source': 'D-arabinose',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'BOP1000_aceEF': {'taxonomy-id': '511145',
#   'strain-description': 'ΔaceEF glucose M9 evolved',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'TOL_propanediol': {'supplement': 'propanediol',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'MG1655_trimethoprim': {'supplement': 'trimethoprim',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '30 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'SSW_GLU_GLY': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(4) or glycerol(2.5)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'tpiPAE': {'taxonomy-id': '511145',
#   'strain-description': 'P. aerophilum tpiA',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'gallium-nitrate': {'supplement': 'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '30 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(1)',
#   'nitrogen-source': '(NH4)2SO4(1)',
#   'phosphorous-source': 'K2HPO4(5.3) KH2PO4(2)',
#   'sulfur-source': '(NH4)2SO4(1) MgSO4',
#   'calcium-source': 'CaCl2(0.1)'},
#  'sdh': {'taxonomy-id': '511145',
#   'strain-description': 'ΔsdhCDAB glucose M9 pre-evolved',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'TOL_isobutyric_acid': {'supplement': 'isobutyric acid',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'},
#  'pgiBME': {'taxonomy-id': '511145',
#   'strain-description': 'B. melitensis pgi',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'SER': {'taxonomy-id': '511145',
#   'strain-description': 'ΔsdaA ΔsdaB ΔtdcG ΔglyA',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': "glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'calcium-source': 'CaCl2(0.1)'},
#  'pgiKO': {'taxonomy-id': '511145',
#   'strain-description': 'Δpgi',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'tpiVCH': {'taxonomy-id': '511145',
#   'strain-description': 'V. cholerae tpiA',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'BOP1000_rpe': {'taxonomy-id': '511145',
#   'strain-description': 'Δrpe glucose M9 evolved',
#   'base-media': 'M9',
#   'temperature': '37 celsius',
#   'carbon-source': 'glucose(4)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'C13': {'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'U-13C glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'calcium-source': 'CaCl2(0.1)'},
#  'SSW_AC': {'strain-description': 'WT',
#   'taxonomy-id': '511145',
#   'nitrogen-source': 'NH4Cl(1)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'base-media': 'M9',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'carbon-source': 'acetate(4)',
#   'supplement': 'NaCl(0.5g/L) trace elements',
#   'temperature': '37 celsius',
#   'calcium-source': 'CaCl2(0.1)'},
#  'TOL_2,3-butanediol': {'supplement': '2 3-butanediol',
#   'taxonomy-id': '511145',
#   'strain-description': 'WT',
#   'temperature': '37 celsius',
#   'base-media': 'M9',
#   'carbon-source': 'glucose(2)',
#   'nitrogen-source': 'NH4Cl(1)',
#   'phosphorous-source': 'KH2PO4(3) Na2HPO4(6.8)',
#   'sulfur-source': 'MgSO4(0.24)',
#   'calcium-source': 'CaCl2(0.1)'}}

# %%
# So that rows will always contain the same amount of columns
all_muts_df = all_muts_df.replace('', "None")
display(all_muts_df.shape, all_muts_df.head())
# Out:
# (3921, 38)
#   index  exp  ale  flask  isolate  tech_rep  presence  Position Mutation Type  \
# 0     9  42C    1    124        1         1       1.0    702352           DEL
# 1    10  42C    1    124        1         1       1.0   1308318           SNP
# 2    11  42C    1    124        1         1       1.0   3815859           DEL
# 3    12  42C    1    124        1         1       1.0   4187550           SNP
# 4    13  42C    1    124        1         1       1.0   4400313           SNP
#
#   Sequence Change                   Details mutation target annotation  \
# 0          Δ21 bp  coding (380‑400/1149 nt)                       nagA
# 1             G→C           R110G (CGT→GGT)                       clsA
# 2          Δ82 bp                      None                        rph
# 3             C→T           A734V (GCG→GTG)                       rpoC
# 4             A→C             D9A (GAT→GCT)                        hfq
#
#   Reference Seq     sample sample type exp ALE  coding               range  \
# 0           NaN  1 124 1 1       clone   42C 1    True    (702352, 702372)
# 1           NaN  1 124 1 1       clone   42C 1    True  (1308318, 1308318)
# 2           NaN  1 124 1 1       clone   42C 1    True  (3815859, 3815940)
# 3           NaN  1 124 1 1       clone   42C 1    True  (4187550, 4187550)
# 4           NaN  1 124 1 1       clone   42C 1    True  (4400313, 4400313)
#
#   gene RegulonDB ID                                   genetic features   oriC  \
# 0    {ECK120000625}  [{'name': 'nagA', 'RegulonDB ID': 'ECK12000062...  False
# 1    {ECK120001556}  [{'name': 'clsA', 'RegulonDB ID': 'ECK12000155...  False
# 2    {ECK120000854}  [{'name': 'rph', 'RegulonDB ID': 'ECK120000854...  False
# 3    {ECK120000886}  [{'name': 'rpoC', 'RegulonDB ID': 'ECK12000088...  False
# 4    {ECK120000431}  [{'name': 'hfq', 'RegulonDB ID': 'ECK120000431...  False
#
#    pseudogene TFBS promoter RBS attenuator terminator terminator  genetic  \
# 0       False   {}       {}  {}                    {}         {}     True
# 1       False   {}       {}  {}                    {}         {}     True
# 2       False   {}       {}  {}        {ECK125144791}         {}     True
# 3       False   {}       {}  {}                    {}         {}     True
# 4       False   {}       {}  {}                    {}         {}     True
#
#                                     genomic features  \
# 0  [{'name': 'nagA', 'RegulonDB ID': 'ECK12000062...
# 1  [{'name': 'clsA', 'RegulonDB ID': 'ECK12000155...
# 2  [{'name': 'rph-pyrE attenuator terminator', 'R...
# 3  [{'name': 'rpoC', 'RegulonDB ID': 'ECK12000088...
# 4  [{'name': 'hfq', 'RegulonDB ID': 'ECK120000431...
#
#                                genetic feature links  \
# 0                 {'ECK120000625': ['ECK120000625']}
# 1                 {'ECK120001556': ['ECK120001556']}
# 2  {'ECK120000854': ['ECK120000854'], 'ECK1200007...
# 3                 {'ECK120000886': ['ECK120000886']}
# 4                 {'ECK120000431': ['ECK120000431']}
#
#                                              operons  \
# 0  [{'name': 'nagBAC-umpH', 'RegulonDB ID': 'ECK1...
# 1  [{'name': 'clsA-yciU', 'RegulonDB ID': 'ECK125...
# 2  [{'name': 'rph-pyrE', 'RegulonDB ID': 'ECK1200...
# 3  [{'name': 'rplKAJL-rpoBC', 'RegulonDB ID': 'EC...
# 4  [{'name': 'yjeF-tsaE-amiB-mutL-miaA-hfq-hflXKC...
#
#                                         operon links  \
# 0                 {'ECK125162049': ['ECK120000625']}
# 1                 {'ECK125147415': ['ECK120001556']}
# 2  {'ECK120014627': ['ECK120000854', 'ECK12000079...
# 3                 {'ECK120016992': ['ECK120000886']}
# 4                 {'ECK125147410': ['ECK120000431']}
#
#                                           regulators  \
# 0  [{'name': 'PhoP'}, {'name': 'CRP'}, {'name': '...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                  [{'name': 'CRP'}]
#
#                                      regulator links  \
# 0  {'PhoP': ['ECK125162049'], 'CRP': ['ECK1251620...
# 1                                                 {}
# 2                                                 {}
# 3                                                 {}
# 4                          {'CRP': ['ECK125147410']}
#
#                                             pathways  \
# 0  [{'name': 'Galactose metabolism'}, {'name': 'A...
# 1                                                 []
# 2  [{'name': 'Pyrimidine metabolism'}, {'name': '...
# 3  [{'name': 'Purine metabolism'}, {'name': 'Pyri...
# 4                                                 []
#
#                                        pathway links  \
# 0  {'Galactose metabolism': ['ECK125162049'], 'Am...
# 1                                                 {}
# 2  {'Pyrimidine metabolism': ['ECK120014627'], 'D...
# 3  {'Purine metabolism': ['ECK120016992'], 'Pyrim...
# 4                                                 {}
#
#                                                 COGs  \
# 0  [{'name': 'Carbohydrate transport and metaboli...
# 1       [{'name': 'Lipid transport and metabolism'}]
# 2  [{'name': 'Nucleotide transport and metabolism'}]
# 3                        [{'name': 'Transcription'}]
# 4       [{'name': 'Signal transduction mechanisms'}]
#
#                                            COG links
# 0  {'Carbohydrate transport and metabolism': ['EC...
# 1  {'Lipid transport and metabolism': ['ECK125147...
# 2  {'Nucleotide transport and metabolism': ['ECK1...
# 3                {'Transcription': ['ECK120016992']}
# 4  {'Signal transduction mechanisms': ['ECK125147...

# %% [markdown]
# ### mutation to condition association

# %%
for exp, md_d in all_exp_cond_d.items():
    if "calcium-source" not in md_d.keys():
        print(exp)

# %%
from mutil.metadata_categories_for_associations import METADATA_CATEGORIES_FOR_ASSOCIATIONS
print(len(METADATA_CATEGORIES_FOR_ASSOCIATIONS))

for condition in METADATA_CATEGORIES_FOR_ASSOCIATIONS:
    all_muts_df[condition] = all_muts_df["exp"].apply(lambda exp: all_exp_cond_d[exp][condition])
    
all_muts_df = all_muts_df.reset_index(drop=True)
# Out:
# 10

# %%
# The below is the necessary logic without this filtering.
exp_target_cond_df = all_muts_df.copy()
display(exp_target_cond_df.shape, exp_target_cond_df.head())
# Out:
# (3921, 48)
#   index  exp  ale  flask  isolate  tech_rep  presence  Position Mutation Type  \
# 0     9  42C    1    124        1         1       1.0    702352           DEL
# 1    10  42C    1    124        1         1       1.0   1308318           SNP
# 2    11  42C    1    124        1         1       1.0   3815859           DEL
# 3    12  42C    1    124        1         1       1.0   4187550           SNP
# 4    13  42C    1    124        1         1       1.0   4400313           SNP
#
#   Sequence Change                   Details mutation target annotation  \
# 0          Δ21 bp  coding (380‑400/1149 nt)                       nagA
# 1             G→C           R110G (CGT→GGT)                       clsA
# 2          Δ82 bp                      None                        rph
# 3             C→T           A734V (GCG→GTG)                       rpoC
# 4             A→C             D9A (GAT→GCT)                        hfq
#
#   Reference Seq     sample sample type exp ALE  coding               range  \
# 0           NaN  1 124 1 1       clone   42C 1    True    (702352, 702372)
# 1           NaN  1 124 1 1       clone   42C 1    True  (1308318, 1308318)
# 2           NaN  1 124 1 1       clone   42C 1    True  (3815859, 3815940)
# 3           NaN  1 124 1 1       clone   42C 1    True  (4187550, 4187550)
# 4           NaN  1 124 1 1       clone   42C 1    True  (4400313, 4400313)
#
#   gene RegulonDB ID                                   genetic features   oriC  \
# 0    {ECK120000625}  [{'name': 'nagA', 'RegulonDB ID': 'ECK12000062...  False
# 1    {ECK120001556}  [{'name': 'clsA', 'RegulonDB ID': 'ECK12000155...  False
# 2    {ECK120000854}  [{'name': 'rph', 'RegulonDB ID': 'ECK120000854...  False
# 3    {ECK120000886}  [{'name': 'rpoC', 'RegulonDB ID': 'ECK12000088...  False
# 4    {ECK120000431}  [{'name': 'hfq', 'RegulonDB ID': 'ECK120000431...  False
#
#    pseudogene TFBS promoter RBS attenuator terminator terminator  genetic  \
# 0       False   {}       {}  {}                    {}         {}     True
# 1       False   {}       {}  {}                    {}         {}     True
# 2       False   {}       {}  {}        {ECK125144791}         {}     True
# 3       False   {}       {}  {}                    {}         {}     True
# 4       False   {}       {}  {}                    {}         {}     True
#
#                                     genomic features  \
# 0  [{'name': 'nagA', 'RegulonDB ID': 'ECK12000062...
# 1  [{'name': 'clsA', 'RegulonDB ID': 'ECK12000155...
# 2  [{'name': 'rph-pyrE attenuator terminator', 'R...
# 3  [{'name': 'rpoC', 'RegulonDB ID': 'ECK12000088...
# 4  [{'name': 'hfq', 'RegulonDB ID': 'ECK120000431...
#
#                                genetic feature links  \
# 0                 {'ECK120000625': ['ECK120000625']}
# 1                 {'ECK120001556': ['ECK120001556']}
# 2  {'ECK120000854': ['ECK120000854'], 'ECK1200007...
# 3                 {'ECK120000886': ['ECK120000886']}
# 4                 {'ECK120000431': ['ECK120000431']}
#
#                                              operons  \
# 0  [{'name': 'nagBAC-umpH', 'RegulonDB ID': 'ECK1...
# 1  [{'name': 'clsA-yciU', 'RegulonDB ID': 'ECK125...
# 2  [{'name': 'rph-pyrE', 'RegulonDB ID': 'ECK1200...
# 3  [{'name': 'rplKAJL-rpoBC', 'RegulonDB ID': 'EC...
# 4  [{'name': 'yjeF-tsaE-amiB-mutL-miaA-hfq-hflXKC...
#
#                                         operon links  \
# 0                 {'ECK125162049': ['ECK120000625']}
# 1                 {'ECK125147415': ['ECK120001556']}
# 2  {'ECK120014627': ['ECK120000854', 'ECK12000079...
# 3                 {'ECK120016992': ['ECK120000886']}
# 4                 {'ECK125147410': ['ECK120000431']}
#
#                                           regulators  \
# 0  [{'name': 'PhoP'}, {'name': 'CRP'}, {'name': '...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                  [{'name': 'CRP'}]
#
#                                      regulator links  \
# 0  {'PhoP': ['ECK125162049'], 'CRP': ['ECK1251620...
# 1                                                 {}
# 2                                                 {}
# 3                                                 {}
# 4                          {'CRP': ['ECK125147410']}
#
#                                             pathways  \
# 0  [{'name': 'Galactose metabolism'}, {'name': 'A...
# 1                                                 []
# 2  [{'name': 'Pyrimidine metabolism'}, {'name': '...
# 3  [{'name': 'Purine metabolism'}, {'name': 'Pyri...
# 4                                                 []
#
#                                        pathway links  \
# 0  {'Galactose metabolism': ['ECK125162049'], 'Am...
# 1                                                 {}
# 2  {'Pyrimidine metabolism': ['ECK120014627'], 'D...
# 3  {'Purine metabolism': ['ECK120016992'], 'Pyrim...
# 4                                                 {}
#
#                                                 COGs  \
# 0  [{'name': 'Carbohydrate transport and metaboli...
# 1       [{'name': 'Lipid transport and metabolism'}]
# 2  [{'name': 'Nucleotide transport and metabolism'}]
# 3                        [{'name': 'Transcription'}]
# 4       [{'name': 'Signal transduction mechanisms'}]
#
#                                            COG links temperature  \
# 0  {'Carbohydrate transport and metabolism': ['EC...  42 celsius
# 1  {'Lipid transport and metabolism': ['ECK125147...  42 celsius
# 2  {'Nucleotide transport and metabolism': ['ECK1...  42 celsius
# 3                {'Transcription': ['ECK120016992']}  42 celsius
# 4  {'Signal transduction mechanisms': ['ECK125147...  42 celsius
#
#   carbon-source                   supplement strain-description taxonomy-id  \
# 0    glucose(4)  NaCl(0.5g/L) trace elements                 WT      511145
# 1    glucose(4)  NaCl(0.5g/L) trace elements                 WT      511145
# 2    glucose(4)  NaCl(0.5g/L) trace elements                 WT      511145
# 3    glucose(4)  NaCl(0.5g/L) trace elements                 WT      511145
# 4    glucose(4)  NaCl(0.5g/L) trace elements                 WT      511145
#
#   base-media nitrogen-source      phosphorous-source sulfur-source  \
# 0         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)
# 1         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)
# 2         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)
# 3         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)
# 4         M9        NH4Cl(1)  KH2PO4(3) Na2HPO4(6.8)   MgSO4(0.24)
#
#   calcium-source
# 0     CaCl2(0.1)
# 1     CaCl2(0.1)
# 2     CaCl2(0.1)
# 3     CaCl2(0.1)
# 4     CaCl2(0.1)

# %%
unique_condition_set = set()
for cond_cat in METADATA_CATEGORIES_FOR_ASSOCIATIONS:
    unique_condition_set |= set(exp_target_cond_df[cond_cat].unique())
unique_condition_set
# Out:
# {'(NH4)2SO4(1)',
#  '(NH4)2SO4(1) MgSO4',
#  '(NH4)2SO4(2)',
#  '(NH4)2SO4(2) MgSO4(0.12)',
#  '2 3-butanediol',
#  '30 celsius',
#  '37 celsius',
#  '42 celsius',
#  '511145',
#  'B. melitensis pgi',
#  'C13H10N2O(0.168184)',
#  'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#  'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#  'CaCl2(0.1)',
#  'CaCl2(0.1mM)',
#  'D-2-deoxyribose',
#  'D-arabinose',
#  'D-lyxose',
#  'E. coli K-12 MG1655 pCA24N-fucO',
#  'FeSO4(20uM) sodium citrate(10mM)',
#  'GMOS',
#  'H. sapien pgi',
#  'H. sapien tpiA',
#  'JCL260',
#  'K2HPO4(5.3) KH2PO4(2)',
#  'KH2PO4(13.6)',
#  'KH2PO4(3) Na2HPO4(6.78)',
#  'KH2PO4(3) Na2HPO4(6.8)',
#  'LB',
#  'M63',
#  'M9',
#  'MS57',
#  'MgSO4(0.24)',
#  'MgSO4(1mM)',
#  'NH4Cl(1)',
#  'NaCl(0.5g/L) trace elements',
#  'P. aerophilum pgi',
#  'P. aerophilum tpiA',
#  'PQ(0.8mM)',
#  'U-13C glucose(2)',
#  'V. cholerae pgi',
#  'V. cholerae tpiA',
#  'WT',
#  'acetate(4)',
#  'adipic acid',
#  'bla-TEM-1',
#  'ceftazidime',
#  'chloramphenicol',
#  'chloramphenicol(25)',
#  'coumaric acid',
#  'doxycycline',
#  'ethylene glycol(30mM)',
#  'gentamycin(0.03)',
#  'glucose(1)',
#  'glucose(2)',
#  'glucose(3)',
#  'glucose(4)',
#  'glucose(4) or acetate(4)',
#  'glucose(4) or glycerol(2.5)',
#  'glucose(4) or xylose(4)',
#  'glucose-evolved BOP1000',
#  'glutaric acid',
#  'glycerol(2.5)',
#  "glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#  'hexamethylenediamine',
#  'hexanoic acid',
#  'isobutanol(8g/L)',
#  'isobutyric acid',
#  'm-tartrate',
#  'monomethyl succinate',
#  'n-butanol',
#  'none',
#  'octanoic acid',
#  'pBGT',
#  'propanediol',
#  'putrescine',
#  'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)',
#  'trimethoprim',
#  'xylose(4)',
#  'Δgnd glucose M9 pre-evolved',
#  'Δpgi',
#  'Δpgi glucose M9 pre-evolved',
#  'ΔptsHI-crr glucose M9 pre-evolved',
#  'ΔsdaA ΔsdaB ΔtdcG ΔglyA',
#  'ΔsdhCDAB glucose M9 pre-evolved',
#  'ΔtpiA',
#  'ΔtpiA glucose M9 pre-evolved'}

# %%
feat_cond_df = pd.DataFrame()
for _, r in exp_target_cond_df.iterrows():
    for feat in r[FEAT_ANNOT]:
        for cond_col in METADATA_CATEGORIES_FOR_ASSOCIATIONS:
            if r[cond_col] in unique_condition_set:   # I'm not quite sure why I had to check this in the legacy code.
                feat_cond_df = feat_cond_df.append({"feature": feat["name"], "condition":r[cond_col]}, ignore_index=True)
display(len(feat_cond_df), feat_cond_df.head())
# Out:
# 70120
#                      condition feature
# 0                   42 celsius    nagA
# 1                   glucose(4)    nagA
# 2  NaCl(0.5g/L) trace elements    nagA
# 3                           WT    nagA
# 4                       511145    nagA

# %% [markdown]
# TODO: Now that this logic is being used for multiple feature types (therefore multiple times), should extract it into a util script file

# %%
from statsmodels.stats import multitest
import scipy


def get_contingency_table(count_mat, row_name, col_name):
    row_col_count = count_mat.loc[row_name, col_name]
    row_not_col_sum_count = count_mat.loc[row_name].sum() - row_col_count
    not_row_col_sum_count = count_mat.T.loc[col_name].sum() - row_col_count
    all_mat_sum_count = count_mat.sum(axis=1).sum()
    not_row_not_col_sum_count = all_mat_sum_count - \
        row_col_count - row_not_col_sum_count - not_row_col_sum_count
    contingency_table = [
        [row_col_count, row_not_col_sum_count],
        [not_row_col_sum_count, not_row_not_col_sum_count]
    ]
    return contingency_table


test_df = pd.DataFrame([[1, 2, 3],
                        [4, 5, 6]],
                       index=["y1", "y2"],
                       columns=["x1", "x2", "x3"])
contingency_table = get_contingency_table(test_df, "y2", "x3")
expected_contingency_table = [[6, 9], [3, 3]]
assert(contingency_table == expected_contingency_table)


def get_multiple_hypothesis_correction(pval_df):
    # Dataframe seemed to be designed to iterate by column more easily than row (see df.iteritems())
    # Have to combine all p-value columns because multitest.multipletests only takes 1D array inputs.
    pval_l = []
    for col in list(pval_df.columns.values):
        pval_l += list(pval_df[col])
    corrected_pval_result = multitest.multipletests(
        pvals=pval_l,
        alpha=ASSOC_ALPHA,
        method=MULTI_HYP_CORR_METHOD)

    # The following splits the multitest.multipletests 1D array output into the same shape, though transposed.
    corrected_pval_l = corrected_pval_result[1]
    df_col_len = pval_df.shape[0]
    corrected_pval_mat = [corrected_pval_l[i:i+df_col_len]
                          for i in range(0, len(corrected_pval_l), df_col_len)]

    # building df with new p-values
    corrected_pval_df = pval_df.copy()
    for outer_l_idx in range(0, len(corrected_pval_df.columns)):
        for inner_l_idx in range(0, len(corrected_pval_df)):
            corrected_pval = corrected_pval_mat[outer_l_idx][inner_l_idx]
            corrected_pval_df.iloc[inner_l_idx, outer_l_idx] = corrected_pval
    return corrected_pval_df


# def get_enrich_genetic_target_df(cond_col, mut_df):
def get_enrich_genetic_target_df(feat_cond_df):
    # Creates tables of counts between each mutation and unique condition.
    cross_counts_df = pd.crosstab(
        feat_cond_df["feature"], feat_cond_df["condition"]
    )

    # To reuse the same DF indeces without having to remake it.
    enrich_odds_ratio_df = cross_counts_df.copy()
    enrich_pvals_df = cross_counts_df.copy()

    for cond in cross_counts_df.columns.values:
        for mut_target in cross_counts_df.index:
            contingency_table = get_contingency_table(cross_counts_df, mut_target, cond)
            odds_ratio, p_val = scipy.stats.fisher_exact(contingency_table, alternative="greater")
            enrich_odds_ratio_df.loc[mut_target, cond] = odds_ratio
            enrich_pvals_df.loc[mut_target, cond] = p_val

    enriched_pvals_df = get_multiple_hypothesis_correction(enrich_pvals_df)

    return enrich_odds_ratio_df, enrich_pvals_df

# %%
enrich_odds_ratio_df, enrich_pvals_df = get_enrich_genetic_target_df(feat_cond_df)

# %%
signif_genomic_feat_cond_json = []
mut_feat_cond_assoc_json = []
for (mut_serial, row) in enrich_pvals_df.iterrows():
    for cond in row.index:
        p_val = enrich_pvals_df.at[mut_serial, cond]
        odds_ratio = enrich_odds_ratio_df.at[mut_serial, cond]
        mut_feat_cond_assoc_json.append({"mutated features": mut_serial, "condition": cond, "odd ratio": odds_ratio, "p value":p_val})
        if odds_ratio > 1 and p_val < ASSOC_ALPHA:
            signif_genomic_feat_cond_json.append({"mutated features": mut_serial, "condition": cond, "odd ratio": odds_ratio, "p value":p_val})

# %%
assoc_df = pd.DataFrame()
for d in mut_feat_cond_assoc_json:
    assoc_df = assoc_df.append(d, ignore_index=True)
assoc_df = assoc_df.set_index("mutated features")
assoc_df.to_csv("./data/supp/mut_geno_cond_assocs.csv")

# %%
import pickle
f = open("./data/signif_genomic_feat_cond_json.pkl", 'wb')
pickle.dump(signif_genomic_feat_cond_json, f)
f.close()

# %%
signf_assoc_feat_cond_d = {d["mutated features"]:set() for d in signif_genomic_feat_cond_json}
for d in signif_genomic_feat_cond_json:
    target = d["mutated features"]
    condition = d["condition"]
    if target in signf_assoc_feat_cond_d.keys():
        signf_assoc_feat_cond_d[target].add(condition)
    else:
        signf_assoc_feat_cond_d[target] = {condition}
signf_assoc_feat_cond_d
# Out:
# {'C0343': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'C0465': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'aaeR': {'LB'},
#  'aas': {'glucose(4) or xylose(4)'},
#  'abgA': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'abgB': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'abgR': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'abgR attenuator terminator': {'LB',
#   'bla-TEM-1',
#   'ceftazidime',
#   'pBGT',
#   'ΔtpiA'},
#  'abgR terminator': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'abgT': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'LB',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'ceftazidime',
#   'glucose(2)'},
#  'abpA': {'hexanoic acid'},
#  'aceE': {'PQ(0.8mM)', 'glucose-evolved BOP1000'},
#  'ackA': {'Δpgi glucose M9 pre-evolved'},
#  'acnAp1': {'LB'},
#  'acpSp2': {'adipic acid'},
#  'acpSp3': {'adipic acid'},
#  'acrA': {'trimethoprim'},
#  'acrAB attenuator terminator': {'doxycycline'},
#  'acrB': {'30 celsius', 'chloramphenicol'},
#  'acrR': {'30 celsius', 'WT', 'chloramphenicol', 'doxycycline', 'glucose(4)'},
#  'acrR attenuator terminator': {'trimethoprim'},
#  'actP': {'D-lyxose'},
#  'alaS': {'LB'},
#  'aldA TFBS': {'D-2-deoxyribose', 'P. aerophilum tpiA'},
#  'aldA/gapC_2': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'allD': {'adipic acid'},
#  'alsB': {'LB'},
#  'ampC': {'hexamethylenediamine'},
#  'ampD': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'ampH': {'gentamycin(0.03)'},
#  'ampHp1': {'gentamycin(0.03)'},
#  'ampHp2': {'gentamycin(0.03)'},
#  'ansB terminator': {'LB'},
#  'araA': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'araB': {'LB'},
#  'araB/araC': {'LB', 'ceftazidime', 'pBGT'},
#  'araBAD attenuator terminator': {'LB'},
#  'araC': {'LB', 'ceftazidime', 'pBGT'},
#  'araD': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'araE-ygeA attenuator terminator': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'arfB': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'argI': {'LB'},
#  'argP': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'arnA': {'PQ(0.8mM)', 'glucose-evolved BOP1000'},
#  'aroE': {'LB'},
#  'aroP': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'arpA': {'octanoic acid'},
#  'arsC/yhiS_1': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   '30 celsius',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'ascB': {'LB'},
#  'aslB': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)'},
#  'asnB/umpH': {'Δgnd glucose M9 pre-evolved'},
#  'asnC': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'asnCp': {'LB'},
#  'asnS': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'aspC/ompF': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'atpG': {'gentamycin(0.03)'},
#  'atpI/rsmG': {'coumaric acid'},
#  'b0725': {'ΔsdhCDAB glucose M9 pre-evolved'},
#  'baeR': {'LB'},
#  'baeS': {'LB', 'bla-TEM-1', 'ceftazidime'},
#  'barA': {'2 3-butanediol'},
#  'bcsC': {'LB'},
#  'bdcA': {'FeSO4(20uM) sodium citrate(10mM)'},
#  'betT/pdeL': {'FeSO4(20uM) sodium citrate(10mM)'},
#  'bioAp': {'hexanoic acid'},
#  'bioH': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'bisC': {'LB'},
#  'btsS': {'V. cholerae tpiA'},
#  'carB': {'B. melitensis pgi'},
#  'cas1': {'hexamethylenediamine'},
#  'cfa': {'LB'},
#  'chaA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'cheA': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'cheB': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'cheW': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'cheWp5': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'cheY': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'cheZ': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'cho': {'H. sapien pgi'},
#  'chpS': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'cirA': {'glucose(4) or glycerol(2.5)'},
#  'clpA': {'D-arabinose'},
#  'cmrp': {'30 celsius', 'chloramphenicol', 'glucose(4)'},
#  'cmrp2': {'30 celsius', 'chloramphenicol'},
#  'cmtA': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'comRp': {'octanoic acid'},
#  'comRp3': {'octanoic acid'},
#  'cpdB': {'LB'},
#  'cpxA': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'cpxR': {'Δpgi'},
#  'creAp2': {'n-butanol'},
#  'crlp1': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'crlp2': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'crr': {'30 celsius', 'glycerol(2.5)', 'Δpgi'},
#  'cspC': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)',
#   'n-butanol'},
#  'cspC/yobF': {'acetate(4)'},
#  'cspE/crcB': {'glucose(4) or xylose(4)'},
#  'csrA': {'gentamycin(0.03)'},
#  'csrC': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'cutC': {'V. cholerae tpiA'},
#  'cvrA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'cyaA': {'30 celsius',
#   'CaCl2(0.1)',
#   'KH2PO4(3) Na2HPO4(6.8)',
#   'M9',
#   'MgSO4(0.24)',
#   'NaCl(0.5g/L) trace elements',
#   'WT',
#   'glycerol(2.5)',
#   'ΔptsHI-crr glucose M9 pre-evolved'},
#  'cycA': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'cydAB TFBS': {'hexanoic acid'},
#  'cydAp2': {'hexanoic acid'},
#  'cydX': {'octanoic acid'},
#  'cynR': {'hexamethylenediamine'},
#  'cyoA': {'gentamycin(0.03)'},
#  'cyoAp': {'GMOS'},
#  'cysB': {'GMOS'},
#  'cysDp': {'ΔsdhCDAB glucose M9 pre-evolved'},
#  'dbpA': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'dbpAp2': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'dcp': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'ddlA': {'gentamycin(0.03)'},
#  'ddpA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'dgcM': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'dgoD': {'LB'},
#  'dgoK': {'LB'},
#  'dgoT': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'dinD/yicG': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'dmlRp3': {'m-tartrate'},
#  'dnaG': {'xylose(4)'},
#  'dnaKp2': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'dnaKp3': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'dnaN': {'LB'},
#  'dppD': {'LB'},
#  'dusAp9': {'propanediol'},
#  'dusB': {'42 celsius'},
#  'dusB-fis TFBS': {'octanoic acid'},
#  'dusBp': {'octanoic acid'},
#  'ebgA': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'ebgAp': {'acetate(4)'},
#  'eda TFBS': {'m-tartrate'},
#  'edd-eda TFBS': {'m-tartrate'},
#  'elyC': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)'},
#  'emrB': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)'},
#  'emrD': {'U-13C glucose(2)'},
#  'endA RBS': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'endAp1': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'endAp2': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'eno': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'entSp1': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   '30 celsius',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'entSp2': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   '30 celsius',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'envR/acrE': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C13H10N2O(0.168184)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'envZ': {'LB', 'ceftazidime', 'pBGT'},
#  'eutH': {'xylose(4)'},
#  'eutS/maeB': {'LB'},
#  'fabR': {'propanediol'},
#  'fdhF attenuator terminator': {'glucose(4) or xylose(4)'},
#  'fdhFp': {'glucose(4) or xylose(4)'},
#  'fdnG': {'Δgnd glucose M9 pre-evolved'},
#  'fdnGHI TFBS': {'D-2-deoxyribose'},
#  'fdnGHI fdnGHI TFBS': {'D-2-deoxyribose'},
#  'fdoG': {'LB'},
#  'fdrA': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'feaR TFBS': {'D-2-deoxyribose', 'P. aerophilum tpiA'},
#  'fecA': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   '30 celsius',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'fecB': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'fecE': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   '30 celsius',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'fepAp': {'M63'},
#  'fepDp1': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   '30 celsius',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'fepDp2': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   '30 celsius',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'fepE': {'ΔsdhCDAB glucose M9 pre-evolved'},
#  'fesp': {'M63'},
#  'ffh': {'LB'},
#  'fhuA': {'gentamycin(0.03)'},
#  'fimA': {'V. cholerae tpiA', 'acetate(4)'},
#  'fimAICDFGH TFBS': {'xylose(4)'},
#  'fimAp': {'LB'},
#  'fimB/fimE': {'LB'},
#  'fimE': {'LB'},
#  'fimI': {'LB'},
#  'fimZ': {'glycerol(2.5)'},
#  'fiu': {'glucose(4) or xylose(4)'},
#  'fkpA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'flgD': {'acetate(4)'},
#  'flhA': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'flhB': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'flhBAE TFBS': {'30 celsius',
#   'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'flhBp': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'flhC': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'flhCp3': {'30 celsius'},
#  'flhD': {'30 celsius'},
#  'flhDC TFBS': {'30 celsius',
#   'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'flhDC attenuator terminator': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'flhDC flhDC TFBS': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'flhDp': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'flhE': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'fliAZ-tcyJ TFBS': {'isobutyric acid'},
#  'fliAZ-tcyJ fliAZ-tcyJ TFBS': {'isobutyric acid'},
#  'fliDST TFBS': {'isobutyric acid'},
#  'fliE fliFGHIJK TFBS': {'isobutyric acid'},
#  'fliFGHIJK fliE fliE TFBS': {'isobutyric acid'},
#  'fliK': {'acetate(4)'},
#  'fliLMNOPQR TFBS': {'isobutyric acid'},
#  'fnr': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'fnr TFBS': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'fnrS': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'fnrS TFBS': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'fnrS terminator': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'fnrSp': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'fnrp': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'folA': {'30 celsius', 'WT', 'glucose(4)', 'trimethoprim'},
#  'folAp': {'30 celsius', 'glucose(4)', 'trimethoprim'},
#  'folE': {'trimethoprim'},
#  'fpr': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C13H10N2O(0.168184)',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'frc': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'frlA': {'LB'},
#  'frmR/yaiO': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'fruK': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'frvA': {'LB'},
#  'frvB': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'fsaB': {'LB'},
#  'ftsI': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)'},
#  'ftsN': {'B. melitensis pgi'},
#  'fucP': {'D-arabinose'},
#  'fucR': {'D-arabinose'},
#  'fusA': {'gentamycin(0.03)'},
#  'gabT': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'gadBC TFBS': {'D-2-deoxyribose', 'P. aerophilum tpiA'},
#  'gadBC gadBC gadBC TFBS': {'D-2-deoxyribose', 'P. aerophilum tpiA'},
#  'galP attenuator terminator': {'glucose(4)', 'ΔtpiA'},
#  'galP galP TFBS': {'glucose(4)', 'ΔtpiA'},
#  'galR': {'H. sapien tpiA', 'glucose(4)', 'ΔtpiA glucose M9 pre-evolved'},
#  'galU': {'LB'},
#  'gatY/fbaB': {'hexamethylenediamine'},
#  'gcvAp': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'gcvB': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'gcvB gcvA TFBS': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'gcvH': {'D-arabinose'},
#  'gcvRp': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'gcvT': {'acetate(4)'},
#  'ggt': {'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins'},
#  'glf': {'acetate(4)'},
#  'glgBp': {'LB'},
#  'glgP': {'42 celsius'},
#  'glkp': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'glkp1': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'glmU': {'n-butanol'},
#  'glnA': {'LB'},
#  'glnD': {'GMOS', 'ΔsdhCDAB glucose M9 pre-evolved'},
#  'glnX': {'PQ(0.8mM)', 'glucose-evolved BOP1000'},
#  'glpEGR terminator': {'glucose(4) or glycerol(2.5)'},
#  'glpFKX TFBS': {'30 celsius', 'glycerol(2.5)'},
#  'glpK': {'30 celsius',
#   'CaCl2(0.1)',
#   'KH2PO4(3) Na2HPO4(6.8)',
#   'M9',
#   'MgSO4(0.24)',
#   'NaCl(0.5g/L) trace elements',
#   'WT',
#   'glucose(4) or glycerol(2.5)',
#   'glycerol(2.5)'},
#  'glpR': {'glucose(4) or glycerol(2.5)'},
#  'glrK': {'LB'},
#  'gltA': {'PQ(0.8mM)',
#   'glucose-evolved BOP1000',
#   'ΔsdhCDAB glucose M9 pre-evolved'},
#  'gltBDF TFBS': {'P. aerophilum pgi'},
#  'gltP/yjcO': {'H. sapien pgi', 'V. cholerae pgi', 'glucose(4)'},
#  'gltPp1': {'adipic acid'},
#  'gltW': {'LB'},
#  'glxK': {'hexanoic acid'},
#  'glxK/allE': {'30 celsius', 'glycerol(2.5)'},
#  'glyQ': {'isobutyric acid'},
#  'glyV/glyX': {'putrescine'},
#  'glyVp': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'glyY/yjeV': {'glucose(4) or xylose(4)'},
#  'gntR': {'H. sapien pgi'},
#  'gntRp1': {'Δgnd glucose M9 pre-evolved'},
#  'gshA': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'gspD': {'FeSO4(20uM) sodium citrate(10mM)'},
#  'gudD': {'2 3-butanediol'},
#  'gyrB': {'LB'},
#  'hcaT': {'LB'},
#  'hdhA': {'Δgnd glucose M9 pre-evolved'},
#  'hemB': {'gentamycin(0.03)'},
#  'hemBp': {'gentamycin(0.03)'},
#  'hemY': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'hfq': {'42 celsius'},
#  'hisLGDCBHAFI attenuator terminator': {'30 celsius', 'glycerol(2.5)'},
#  'hns TFBS': {'U-13C glucose(2)', 'WT'},
#  'hns/tdk': {'U-13C glucose(2)'},
#  'hnsp': {'30 celsius', 'WT', 'glycerol(2.5)'},
#  'hokA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'hrpA': {'P. aerophilum tpiA'},
#  'hsdM/hsdR': {'LB'},
#  'htrE': {'ΔtpiA glucose M9 pre-evolved'},
#  'hycH': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'hydN': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'hypFp2': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'iap': {'glucose(4)', 'ΔsdhCDAB glucose M9 pre-evolved'},
#  'icd': {'CaCl2(0.1)',
#   'KH2PO4(3) Na2HPO4(6.8)',
#   'M9',
#   'MgSO4(0.24)',
#   'NaCl(0.5g/L) trace elements',
#   'V. cholerae tpiA',
#   'acetate(4)',
#   'glucose(4) or acetate(4)',
#   'Δpgi',
#   'Δpgi glucose M9 pre-evolved'},
#  'idnR': {'adipic acid'},
#  'ilvC': {'LB'},
#  'ilvG_1': {'GMOS', 'JCL260', 'isobutanol(8g/L)'},
#  'ilvG_2': {'Δgnd glucose M9 pre-evolved'},
#  'ilvL': {'Δgnd glucose M9 pre-evolved'},
#  'ilvLXG_1G_2MEDA terminator': {'Δgnd glucose M9 pre-evolved'},
#  'ilvN': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'ilvX': {'LB'},
#  'ilvY': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'infA-serW attenuator terminator': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'insE-2': {'gentamycin(0.03)'},
#  'insEF-2': {'gentamycin(0.03)'},
#  'insF-2': {'gentamycin(0.03)'},
#  'insFp4': {'gentamycin(0.03)'},
#  'insFp5': {'gentamycin(0.03)'},
#  'insH-6': {'glucose(4)', 'Δpgi glucose M9 pre-evolved'},
#  'insH-8/narP': {'octanoic acid'},
#  'insH-9': {'LB'},
#  'insI2': {'adipic acid'},
#  'insJp4': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'intF': {'30 celsius'},
#  'intQ': {'LB'},
#  'iprA': {'gentamycin(0.03)'},
#  'iraMp': {'U-13C glucose(2)'},
#  'iscR': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'isrC': {'chloramphenicol'},
#  'kgtP': {'WT', 'adipic acid', 'glucose(2)', 'glutaric acid'},
#  'kgtPp6': {'LB'},
#  'kgtPp7': {'LB'},
#  'kgtPp8': {'LB'},
#  'kup': {'hexamethylenediamine'},
#  'lacI': {'LB', 'ceftazidime', 'pBGT'},
#  'lacZ': {'LB', 'ceftazidime', 'pBGT'},
#  'lacZYA TFBS': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'lacZYA lacZYA lacZYA TFBS': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'lacZp2': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'lacZp3': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'lacZp4': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'lamB': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'leuLABCD attenuator terminator': {'30 celsius', 'glycerol(2.5)'},
#  'leuP': {'glucose(4) or glycerol(2.5)'},
#  'lhr': {'hexamethylenediamine'},
#  'ligA-ypeB attenuator terminator': {'adipic acid'},
#  'ligAp': {'adipic acid'},
#  'litp1': {'octanoic acid'},
#  'lon': {'doxycycline'},
#  'lonp': {'doxycycline', 'glucose(4)', 'Δpgi glucose M9 pre-evolved'},
#  'lplTp3': {'glucose(4) or xylose(4)'},
#  'lpp': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C13H10N2O(0.168184)',
#   'KH2PO4(13.6)',
#   'glucose(3)',
#   'none'},
#  'lptD': {'doxycycline'},
#  'lpxM': {'doxycycline'},
#  'lrhA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'lrhA attenuator terminator': {'propanediol'},
#  'lrp': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'lrpp': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'lsrK': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  "lysC5'/pgi": {'B. melitensis pgi', 'glucose(4)', 'Δpgi'},
#  'lysU/dtpC': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'malG': {'Δgnd glucose M9 pre-evolved'},
#  'malS': {'LB'},
#  'malT': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'manY': {'WT', 'coumaric acid', 'glucose(2)', 'n-butanol'},
#  'manZ': {'V. cholerae pgi'},
#  'marC': {'n-butanol'},
#  'marR': {'30 celsius', 'LB', 'chloramphenicol', 'doxycycline'},
#  'marR RBS': {'30 celsius', 'chloramphenicol'},
#  'marRAB TFBS': {'30 celsius', 'chloramphenicol'},
#  'marRp': {'30 celsius', 'chloramphenicol'},
#  'mcaS': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'mcaS TFBS': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'mcaSp': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'mdtG/lpxL': {'42 celsius'},
#  'mdtK': {'hexanoic acid'},
#  'melB': {'V. cholerae pgi'},
#  'menC': {'ΔtpiA glucose M9 pre-evolved'},
#  'mepS': {'42 celsius'},
#  'metC': {'LB'},
#  'metE': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'metJ': {'2 3-butanediol', 'WT', 'glucose(2)'},
#  'metK/galP': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'metL': {'glycerol(2.5)'},
#  'metTp': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp attenuator terminator': {'glycerol(2.5)'},
#  'metY-rimP-nusA-infB-rbfA-truB-rpsO-pnp sraG terminator': {'C13H10N2O(0.168184)'},
#  'miaA': {'P. aerophilum pgi'},
#  'micC/ydbK': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'micF': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'mlaE': {'42 celsius'},
#  'mliC': {'LB'},
#  'mltB': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'mltDp4': {'adipic acid'},
#  'mltG': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'mngR': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'mntP TFBS': {'m-tartrate'},
#  'mobA': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'mokA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'motA': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'motAB-cheAW TFBS': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'motAB-cheAW attenuator terminator': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'motAp': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'motB': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'mpl': {'hexamethylenediamine'},
#  'mppA': {'n-butanol'},
#  'mprA': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'WT',
#   'coumaric acid',
#   'glucose(3)',
#   'none'},
#  'mprA-emrAB TFBS': {'coumaric acid'},
#  'mprAp': {'42 celsius', 'coumaric acid'},
#  'mreB': {'octanoic acid', 'putrescine'},
#  'mreC': {'octanoic acid'},
#  'msrQ': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'mstA/C0614': {'30 celsius', 'glycerol(2.5)'},
#  'murA': {'putrescine'},
#  'nadKp2': {'42 celsius'},
#  'nadR': {'coumaric acid'},
#  'nagA': {'glutaric acid', 'ΔtpiA glucose M9 pre-evolved'},
#  'nagC': {'adipic acid',
#   'glutaric acid',
#   'hexamethylenediamine',
#   'ΔtpiA glucose M9 pre-evolved'},
#  'nagCp2': {'ΔtpiA glucose M9 pre-evolved'},
#  'nagE': {'ΔtpiA glucose M9 pre-evolved'},
#  'nagZ': {'H. sapien pgi'},
#  'nanK': {'2 3-butanediol'},
#  'narU': {'H. sapien tpiA',
#   'P. aerophilum tpiA',
#   'V. cholerae tpiA',
#   'glucose(4)'},
#  'nemA': {'ΔtpiA glucose M9 pre-evolved'},
#  'nemR': {'H. sapien tpiA', 'glucose(4)', 'ΔtpiA glucose M9 pre-evolved'},
#  'nhaA': {'LB'},
#  'nhaAR TFBS': {'LB', 'ceftazidime', 'pBGT'},
#  'nhaAp1': {'LB'},
#  'nhaAp2': {'LB'},
#  'nirB': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)'},
#  'nirC': {'U-13C glucose(2)'},
#  'nlpI': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'nmpC TFBS': {'2 3-butanediol', 'LB', 'bla-TEM-1'},
#  'nrdF/proV': {'adipic acid'},
#  'nrfG': {'LB'},
#  'nth/dtpA': {'B. melitensis pgi'},
#  'nudE/yrfF': {'glucose(4)',
#   'Δpgi glucose M9 pre-evolved',
#   'ΔptsHI-crr glucose M9 pre-evolved'},
#  'nuoL': {'V. cholerae pgi'},
#  'ogt': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'ogt TFBS': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'ogtp': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'LB',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'ceftazidime',
#   'glucose(2)'},
#  'ompC': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C13H10N2O(0.168184)',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'ompC TFBS': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'ompC micF TFBS': {'hexanoic acid'},
#  'ompC ompC micF ompC TFBS': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'ompCp1': {'hexanoic acid'},
#  'ompCp2': {'hexanoic acid'},
#  'ompCp3': {'hexanoic acid'},
#  'ompF': {'LB', 'ceftazidime'},
#  'ompG': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'ompR': {'chloramphenicol', 'hexanoic acid'},
#  'opgGH terminator': {'30 celsius', 'glycerol(2.5)'},
#  'opgH': {'hexanoic acid'},
#  'oppA': {'LB'},
#  'oppABCDF attenuator terminator': {'LB'},
#  'otsA': {'LB'},
#  'oxyR': {'FeSO4(20uM) sodium citrate(10mM)',
#   'P. aerophilum tpiA',
#   'V. cholerae tpiA',
#   'glucose(4)'},
#  'paaABCDEFGHIJK TFBS': {'D-2-deoxyribose', 'P. aerophilum tpiA'},
#  'parC': {'GMOS'},
#  'pdeF': {'propanediol'},
#  'pdeK': {'coumaric acid'},
#  'pdxJ': {'adipic acid'},
#  'pepA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'pepN': {'LB'},
#  'pgi': {'B. melitensis pgi', 'glucose(4)', 'Δpgi'},
#  'pgi TFBS': {'B. melitensis pgi'},
#  'pgi/yjbE': {'H. sapien pgi'},
#  'pgip': {'B. melitensis pgi'},
#  'pgpC': {'m-tartrate'},
#  'phnM': {'LB'},
#  'phoB': {'ΔtpiA glucose M9 pre-evolved'},
#  'phoBR sbcDC TFBS': {'ΔtpiA glucose M9 pre-evolved'},
#  'phoBp': {'ΔtpiA glucose M9 pre-evolved'},
#  'phoE TFBS': {'coumaric acid', 'isobutyric acid'},
#  'phoR': {'ΔtpiA glucose M9 pre-evolved'},
#  'pldA': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'pncC': {'LB'},
#  'pnp': {'hexamethylenediamine'},
#  'pnpp': {'C13H10N2O(0.168184)'},
#  'pntA': {'Δpgi'},
#  'pntA RBS': {'Δgnd glucose M9 pre-evolved'},
#  'pntAp': {'Δgnd glucose M9 pre-evolved'},
#  'pntB': {'Δpgi'},
#  'potA': {'gentamycin(0.03)'},
#  'ppa attenuator terminator': {'LB'},
#  'ppap': {'LB'},
#  'ppcp': {'P. aerophilum pgi'},
#  'proL/yejO': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'proQ': {'hexanoic acid'},
#  'proV': {'WT',
#   'adipic acid',
#   'glucose(2)',
#   'glutaric acid',
#   'hexamethylenediamine',
#   'putrescine'},
#  'proVWX TFBS': {'WT', 'coumaric acid', 'glucose(2)'},
#  'prpB/prpC': {'P. aerophilum tpiA', 'glucose(4)'},
#  'prpE': {'hexanoic acid'},
#  'pstA': {'glucose(4)',
#   'Δpgi glucose M9 pre-evolved',
#   'ΔtpiA glucose M9 pre-evolved'},
#  'pstB': {'hexamethylenediamine'},
#  'pstC': {'glucose(4)',
#   'Δpgi glucose M9 pre-evolved',
#   'ΔtpiA glucose M9 pre-evolved'},
#  'pstS': {'putrescine'},
#  'pstSp': {'adipic acid'},
#  'psuG': {'U-13C glucose(2)'},
#  'pta': {'m-tartrate', 'Δpgi glucose M9 pre-evolved'},
#  'ptrA': {'hexanoic acid'},
#  'ptsG': {'glucose(4)', 'ΔtpiA', 'ΔtpiA glucose M9 pre-evolved'},
#  'ptsI': {'P. aerophilum pgi'},
#  'ptsP': {'WT', 'glucose(4) or acetate(4)', 'hexamethylenediamine'},
#  'purF': {'LB'},
#  'purT': {'2 3-butanediol'},
#  'pykF': {'42 celsius',
#   'C13H10N2O(0.168184)',
#   'H. sapien tpiA',
#   'isobutyric acid'},
#  'pyrL': {'LB'},
#  'qmcAp': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'radA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'rapA': {'Δpgi glucose M9 pre-evolved'},
#  'ratA': {'42 celsius'},
#  'ravA': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'rbbA': {'LB'},
#  'rbsDACBKR attenuator terminator': {'hexamethylenediamine'},
#  'rcsA': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'rcsA TFBS': {'isobutyric acid'},
#  'rcsAp': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'rcsB': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'rcsD': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'recQ': {'LB'},
#  'relA': {'2 3-butanediol', 'WT', 'glucose(4) or xylose(4)'},
#  'relA-mazEF TFBS': {'2 3-butanediol'},
#  'relA-mazEF relA-mazEF TFBS': {'2 3-butanediol'},
#  'relAp1': {'2 3-butanediol'},
#  'relAp2': {'2 3-butanediol'},
#  'relAp3': {'2 3-butanediol'},
#  'relAp4': {'2 3-butanediol'},
#  'rfaDp2': {'42 celsius'},
#  'rfaDp3': {'42 celsius'},
#  'rfbD': {'V. cholerae tpiA'},
#  'rffG': {'LB'},
#  'rhaA': {'LB'},
#  'rhaD': {'LB'},
#  'rhaDp': {'LB'},
#  'rhaM': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'rhmD': {'hexanoic acid'},
#  'rho': {'WT', 'acetate(4)', 'coumaric acid'},
#  'rhoL-rho terminator': {'coumaric acid'},
#  'rhoLp': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'rhsA': {'LB'},
#  'rhsB': {'D-arabinose', 'glycerol(2.5)'},
#  'rhsE': {'B. melitensis pgi',
#   'CaCl2(0.1)',
#   'D-lyxose',
#   'H. sapien pgi',
#   'KH2PO4(3) Na2HPO4(6.8)',
#   'M9',
#   'MgSO4(0.24)',
#   'NH4Cl(1)',
#   'NaCl(0.5g/L) trace elements',
#   'P. aerophilum pgi',
#   'U-13C glucose(2)',
#   'V. cholerae pgi',
#   'glucose(4)',
#   'glucose(4) or acetate(4)',
#   'monomethyl succinate'},
#  'rhtB': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'rhtC': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'rhtC/rhtB': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'rhtCp2': {'LB'},
#  'ribC': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'rimI': {'LB'},
#  'rlmD': {'2 3-butanediol'},
#  'rlmDp': {'2 3-butanediol'},
#  'rlmH': {'octanoic acid'},
#  'rmf attenuator terminator': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'rmfp4': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'rmfp5': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'rnb': {'2 3-butanediol', 'glutaric acid'},
#  'rnlA': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'rnpB': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'rnt': {'glutaric acid'},
#  'rob': {'n-butanol'},
#  'rob rob rob TFBS': {'chloramphenicol'},
#  'robp': {'chloramphenicol'},
#  'rpe': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'rph': {'30 celsius',
#   '42 celsius',
#   'CaCl2(0.1)',
#   'FeSO4(20uM) sodium citrate(10mM)',
#   'H. sapien tpiA',
#   'KH2PO4(3) Na2HPO4(6.8)',
#   'M9',
#   'MgSO4(0.24)',
#   'WT',
#   'chloramphenicol',
#   'glucose(4)',
#   'xylose(4)'},
#  'rph-pyrE attenuator terminator': {'42 celsius',
#   'CaCl2(0.1)',
#   'FeSO4(20uM) sodium citrate(10mM)',
#   'H. sapien tpiA',
#   'KH2PO4(3) Na2HPO4(6.8)',
#   'M9',
#   'MgSO4(0.24)',
#   'NH4Cl(1)',
#   'U-13C glucose(2)',
#   'V. cholerae tpiA',
#   'WT',
#   'chloramphenicol',
#   'glucose(4)',
#   'glucose(4) or acetate(4)',
#   'glucose(4) or glycerol(2.5)',
#   'hexamethylenediamine',
#   'n-butanol',
#   'xylose(4)'},
#  'rphp1': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'rplB': {'H. sapien pgi'},
#  'rplD': {'chloramphenicol'},
#  'rplL': {'GMOS'},
#  'rpnC': {'42 celsius'},
#  'rpoA': {'CaCl2(0.1)',
#   'H. sapien pgi',
#   'KH2PO4(3) Na2HPO4(6.8)',
#   'M9',
#   'MgSO4(0.24)',
#   'P. aerophilum pgi',
#   'glucose(4)',
#   'hexanoic acid',
#   'Δpgi'},
#  'rpoB': {'CaCl2(0.1)',
#   'H. sapien tpiA',
#   'KH2PO4(3) Na2HPO4(6.8)',
#   'M9',
#   'MgSO4(0.24)',
#   'U-13C glucose(2)',
#   'WT',
#   'glucose(4)',
#   'isobutyric acid'},
#  'rpoC': {'2 3-butanediol',
#   '42 celsius',
#   'CaCl2(0.1)',
#   'KH2PO4(3) Na2HPO4(6.8)',
#   'M9',
#   'MgSO4(0.24)',
#   'WT',
#   'glucose(4) or acetate(4)',
#   'glutaric acid',
#   'octanoic acid',
#   'xylose(4)'},
#  'rpoD': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'rpoS': {'P. aerophilum pgi', 'Δpgi'},
#  'rpsA': {'hexamethylenediamine', 'putrescine'},
#  'rpsC': {'isobutyric acid'},
#  'rpsMKD-rpoA-rplQ terminator': {'30 celsius', 'glycerol(2.5)'},
#  'rraB': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'rrfB': {'glucose(4)',
#   'Δpgi glucose M9 pre-evolved',
#   'ΔtpiA glucose M9 pre-evolved'},
#  'rrlA': {'LB'},
#  'rrlC': {'JCL260', 'LB', 'isobutanol(8g/L)'},
#  'rrlE/rrfE': {'Δpgi'},
#  'rrlH': {'WT', 'glucose(2)', 'n-butanol'},
#  'rrsB': {'chloramphenicol'},
#  'rseC': {'Δpgi glucose M9 pre-evolved'},
#  'rsfS': {'hexanoic acid'},
#  'rsmC': {'acetate(4)'},
#  'rsmE': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'rtcR': {'glucose(4) or glycerol(2.5)'},
#  'ryhB': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'ryhB TFBS': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'ryhBp': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'safA-ydeO TFBS': {'D-2-deoxyribose'},
#  'sapB': {'hexanoic acid'},
#  'sapD': {'glucose(4) or acetate(4)'},
#  'sapF': {'coumaric acid'},
#  'sbmA': {'gentamycin(0.03)'},
#  'sbmAp': {'gentamycin(0.03)'},
#  'sdaA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)'},
#  'sdhA': {'glucose(4) or xylose(4)'},
#  'sdhB': {'H. sapien pgi'},
#  'secY': {'D-arabinose', 'V. cholerae pgi'},
#  'selD': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'serB': {'doxycycline'},
#  'setA': {'LB'},
#  'sfmH/sfmF': {'hexanoic acid'},
#  'sgrS': {'D-lyxose'},
#  'sgrT': {'D-lyxose'},
#  'slyAp13': {'30 celsius', 'chloramphenicol'},
#  'slyAp14': {'30 celsius', 'chloramphenicol'},
#  'smrA': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'smrAp1': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'speC': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'spf': {'glucose(4)', 'Δpgi glucose M9 pre-evolved'},
#  'spfp': {'glucose(4)', 'Δpgi glucose M9 pre-evolved'},
#  'spoT': {'WT', 'glucose(2)', 'glutaric acid', 'putrescine'},
#  'sraG': {'C13H10N2O(0.168184)'},
#  'srmB': {'adipic acid'},
#  'sspA': {'adipic acid', 'glutaric acid'},
#  'ssrA/intA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'sthA': {'Δpgi'},
#  'sthAp': {'Δpgi'},
#  'stpA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'sucA': {'PQ(0.8mM)',
#   'glucose(4)',
#   'glucose-evolved BOP1000',
#   'ΔsdhCDAB glucose M9 pre-evolved'},
#  'sucB': {'ΔsdhCDAB glucose M9 pre-evolved'},
#  'sulA TFBS': {'Δgnd glucose M9 pre-evolved', 'Δpgi glucose M9 pre-evolved'},
#  'sulAp': {'glucose(4)', 'Δpgi glucose M9 pre-evolved'},
#  'tabAp4': {'LB'},
#  'tap': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'tar': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'tarp': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'tauD': {'glucose(4) or glycerol(2.5)'},
#  'tcyP': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'tdcR': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'thiC': {'LB'},
#  'thiG': {'42 celsius'},
#  'thrA': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'thrW/ykfI': {'42 celsius'},
#  'tnaA': {'acetate(4)'},
#  'torS': {'LB'},
#  'tpiA': {'H. sapien tpiA', 'P. aerophilum tpiA', 'glucose(4)'},
#  'tpiA TFBS': {'H. sapien tpiA', 'glucose(4)'},
#  'tpiAp2': {'P. aerophilum tpiA', 'glucose(4)'},
#  'tqsAp': {'n-butanol'},
#  'trg TFBS': {'D-2-deoxyribose'},
#  'trpS': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'trxB/lrp': {'Δpgi'},
#  'tsr': {'LB'},
#  'tsr/lgoT': {'LB'},
#  'ttcA': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'tufA': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'tufAp1': {'gentamycin(0.03)'},
#  'tufB': {'LB'},
#  'ubiB': {'LB'},
#  'ubiD': {'LB'},
#  'ubiE': {'adipic acid'},
#  'ubiH': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)'},
#  'ubiJ': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'udp': {'LB'},
#  'uidR/hdhA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'umuDC TFBS': {'2 3-butanediol'},
#  'umuDp': {'2 3-butanediol'},
#  'uspE': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'uspEp': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'uvrB': {'adipic acid'},
#  'uvrD': {'LB'},
#  'uxaB TFBS': {'n-butanol'},
#  'valW': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)'},
#  'waaB': {'LB'},
#  'waaJ': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'wbbK': {'hexamethylenediamine'},
#  'wecB': {'LB'},
#  'wecC': {'U-13C glucose(2)'},
#  'wecE': {'GMOS'},
#  'wzyE': {'CaCl2(0.1mM)',
#   'JCL260',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'isobutanol(8g/L)'},
#  'wzzB': {'GMOS'},
#  'xanP': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'xanQ': {'LB'},
#  'xapR/xapB': {'hexamethylenediamine'},
#  'xdhC': {'trimethoprim'},
#  'xylR': {'xylose(4)'},
#  'yabIp': {'LB', 'ceftazidime', 'pBGT'},
#  'yabP': {'H. sapien tpiA'},
#  'yafN': {'LB'},
#  'yafY-ykfBF-yafX-ykfGH-yafW-ykfI attenuator terminator': {'coumaric acid',
#   'isobutyric acid'},
#  'yagF': {'LB'},
#  'yagL': {'adipic acid'},
#  'yahF': {'glucose(4) or xylose(4)'},
#  'yaiU': {'gentamycin(0.03)'},
#  'yaiVp4': {'gentamycin(0.03)'},
#  'yaiW': {'gentamycin(0.03)'},
#  'yaiY': {'gentamycin(0.03)'},
#  'yaiYp5': {'gentamycin(0.03)'},
#  'yaiYp6': {'gentamycin(0.03)'},
#  'yaiZ': {'gentamycin(0.03)'},
#  'yaiZp': {'gentamycin(0.03)'},
#  'yaiZp6': {'gentamycin(0.03)'},
#  'yajQ': {'glucose(4) or glycerol(2.5)'},
#  'ybaL': {'LB'},
#  'ybbLp': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'ybbLp6': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'ybcJ': {'LB'},
#  'ybcM/ylcH': {'glucose(4) or glycerol(2.5)'},
#  'ybeX': {'hexamethylenediamine', 'xylose(4)'},
#  'ybfFp1': {'monomethyl succinate'},
#  'ybhN': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'ybiJ/ybiI': {'glucose(4) or xylose(4)'},
#  'ybiO': {'42 celsius'},
#  'ybjGp': {'30 celsius', 'chloramphenicol'},
#  'ybjL': {'adipic acid'},
#  'ybjQ': {'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins'},
#  'ybjT': {'acetate(4)'},
#  'yceK attenuator terminator': {'30 celsius', 'glycerol(2.5)'},
#  'yciA': {'octanoic acid'},
#  'yciX': {'LB'},
#  'ydaNp': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'ydcA/hokB': {'ΔtpiA glucose M9 pre-evolved'},
#  'ydeK/lsrK': {'adipic acid'},
#  'ydeP TFBS': {'P. aerophilum tpiA'},
#  'ydfE': {'LB'},
#  'ydfV': {'GMOS'},
#  'ydhB': {'LB'},
#  'ydhC': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'ydhR attenuator terminator': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)'},
#  'ydiF': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'ydiK': {'gentamycin(0.03)'},
#  'ydjL': {'LB'},
#  'ydjO': {'LB'},
#  'yeaR': {'2 3-butanediol'},
#  'yebT/rsmF': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'yedN_2': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'yedX': {'doxycycline'},
#  'yedYp4': {'doxycycline'},
#  'yegJ': {'acetate(4)'},
#  'yegK': {'FeSO4(20uM) sodium citrate(10mM)'},
#  'yehD/yehE': {'adipic acid'},
#  'yehX': {'LB'},
#  'yfbP': {'ΔsdhCDAB glucose M9 pre-evolved'},
#  'yfcZ': {'octanoic acid'},
#  'yfdI': {'octanoic acid'},
#  'yfeOp1': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'yfgFp': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'yfgGp7': {'(NH4)2SO4(1)',
#   '(NH4)2SO4(1) MgSO4',
#   'K2HPO4(5.3) KH2PO4(2)',
#   'glucose(1)',
#   'thiaminne hydrochloride(0.3µM) Ga(NO3)3(100mg/L)'},
#  'yfgO': {'adipic acid'},
#  'yfjJ': {'D-lyxose'},
#  'yfjR': {'U-13C glucose(2)'},
#  'ygaH': {'coumaric acid'},
#  'ygaZ': {'coumaric acid'},
#  'ygbI': {'m-tartrate'},
#  'ygcS': {'LB'},
#  'ygeF/ygeG': {'hexamethylenediamine'},
#  'ygfZ': {'PQ(0.8mM)', 'glucose-evolved BOP1000'},
#  'yggF': {'LB'},
#  'yggM attenuator terminator': {'LB'},
#  'yghJ': {'LB'},
#  'yghQ': {'doxycycline'},
#  'yghQp1': {'doxycycline'},
#  'yghQp6': {'doxycycline'},
#  'yghQp7': {'doxycycline'},
#  'yghQp8': {'doxycycline'},
#  'yghR': {'doxycycline'},
#  'yghS': {'doxycycline'},
#  'yghT': {'doxycycline'},
#  'yghTp10': {'doxycycline'},
#  'yghTp11': {'doxycycline'},
#  'yghTp14': {'doxycycline'},
#  'yghTp4': {'doxycycline'},
#  'yghTp5': {'doxycycline'},
#  'yghTp7': {'doxycycline'},
#  'yghTp8': {'doxycycline'},
#  'ygiL': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'ygiS': {'LB'},
#  'ygjH': {'LB'},
#  'ygjQ': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'ygjRp': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'yhaJ': {'LB'},
#  'yhaM': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'yhaO': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'yhdE': {'doxycycline'},
#  'yhdNp': {'30 celsius', 'glycerol(2.5)'},
#  'yhdWXYZ TFBS': {'LB'},
#  'yheS': {'FeSO4(20uM) sodium citrate(10mM)'},
#  'yhfX': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'yhgF': {'LB'},
#  'yhgN': {'LB'},
#  'yhhW': {'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins'},
#  'yhhW attenuator terminator': {'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins'},
#  'yhhX': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'glucose(3)',
#   'none'},
#  'yhhXp4': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'yhhXp5': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'yhhY': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'yhhY ryhB TFBS': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'yhhYp': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'yhhZ': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'yhhZp5': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'yhhZp7': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'yhiL': {'adipic acid'},
#  'yhjV': {'Δgnd glucose M9 pre-evolved'},
#  'yhjY': {'glucose(4) or xylose(4)'},
#  'yiaK': {'LB'},
#  'yiaW': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'yibBp6': {'42 celsius'},
#  'yibV': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'yicC': {'adipic acid'},
#  'yidA': {'LB'},
#  'yieKp3': {'LB', 'bla-TEM-1'},
#  'yieP/rrsC': {'LB'},
#  'yifB': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'yifK': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'yifN/rep': {'LB'},
#  'yihM': {'LB'},
#  'yihQp1': {'octanoic acid'},
#  'yihQp6': {'octanoic acid'},
#  'yihS': {'D-lyxose'},
#  'yihT': {'42 celsius'},
#  'yihW': {'D-lyxose'},
#  'yiiD/yiiE': {'42 celsius'},
#  'yiiM/cpxA': {'LB'},
#  'yiiQ': {'H. sapien tpiA', 'glucose(4)'},
#  'yjgL': {'JCL260', 'LB', 'glucose(3)', 'isobutanol(8g/L)'},
#  'yjgL/argI': {'LB'},
#  'yjgX_1/yjgZ': {'LB'},
#  'yjiJ': {'B. melitensis pgi'},
#  'yjiT': {'LB'},
#  'yjjA': {'LB'},
#  'yjjV': {'LB'},
#  'ykfA-yafZ attenuator terminator': {'coumaric acid'},
#  'ykfH': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C13H10N2O(0.168184)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'WT',
#   'glucose(3)',
#   'none'},
#  'ykiB': {'H. sapien tpiA'},
#  'ylcG/ybcQ': {'glucose(4) or xylose(4)'},
#  'ymfD': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C13H10N2O(0.168184)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'ynaJ': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'yncK_2/yncK_1': {'V. cholerae pgi'},
#  'ynfB': {'P. aerophilum pgi'},
#  'ynfF': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'glucose(2)'},
#  'yobF': {'WT',
#   'glucose(4) or acetate(4)',
#   'glucose(4) or xylose(4)',
#   'n-butanol'},
#  'yodB/serU': {'LB'},
#  'yodD': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'yoeG': {'FeSO4(20uM) sodium citrate(10mM)'},
#  'yojI': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'yphC': {'adipic acid'},
#  'yphFED attenuator terminator': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C13H10N2O(0.168184)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'yphG': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C13H10N2O(0.168184)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'ypjA': {'JCL260', 'isobutanol(8g/L)', 'propanediol'},
#  'ypjC/b2651': {'LB'},
#  'yqhD': {'LB'},
#  'yqhG': {'LB'},
#  'yraJ': {'glucose(4) or xylose(4)'},
#  'yraK': {'gentamycin(0.03)'},
#  'yrbNp': {'ΔptsHI-crr glucose M9 pre-evolved'},
#  'yrdA': {'LB'},
#  'yrfF': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'ΔptsHI-crr glucose M9 pre-evolved'},
#  'yrhA': {'(NH4)2SO4(2)',
#   '(NH4)2SO4(2) MgSO4(0.12)',
#   'C6H5FeO7(0.00049) casamino(5) WT P. aeruginosa toxins',
#   'C6H5FeO7(0.00049) casamino(5) pvdJ KO P. aeruginosa toxins',
#   'KH2PO4(13.6)',
#   'M63',
#   'glucose(3)',
#   'none'},
#  'ysgA': {'P. aerophilum pgi', 'Δpgi'},
#  'ytfBp': {"glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)",
#   'ΔsdaA ΔsdaB ΔtdcG ΔglyA'},
#  'ytfI': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)',
#   'NaCl(0.5g/L) trace elements',
#   'glucose(2)'},
#  'yzgL attenuator terminator': {'E. coli K-12 MG1655 pCA24N-fucO',
#   'chloramphenicol(25)',
#   'ethylene glycol(30mM)'},
#  'zinT': {'glucose(4) or xylose(4)'},
#  'zntB': {'LB', 'bla-TEM-1', 'ceftazidime', 'pBGT', 'ΔtpiA'},
#  'znuA': {'CaCl2(0.1mM)',
#   'KH2PO4(3) Na2HPO4(6.78)',
#   'M63',
#   'MS57',
#   'MgSO4(1mM)'},
#  'zwf TFBS': {'m-tartrate'}}

# %%
def _get_feat_signf_assoc_cond_set(feat_d, mut_conds):
    feat_signf_assoc_cond_set = set()
    if feat_d["name"] in signf_assoc_feat_cond_d.keys():
        
        # Only includes conditions from exp mut comes from, therefore may be subset of signf assoc cond.
        for c in signf_assoc_feat_cond_d[feat_d["name"]]:
            if c in mut_conds:
                feat_signf_assoc_cond_set.add(c)
    
    return feat_signf_assoc_cond_set


def get_feat_signf_assoc_cond_set_json(mut_df_row, feat_annot_name):
    feat_json = []
    for d in mut_df_row[feat_annot_name]:
        feat_d = d.copy()
        mut_conds = list(mut_df_row[METADATA_CATEGORIES_FOR_ASSOCIATIONS])
        feat_d["significantly associated conditions"] = _get_feat_signf_assoc_cond_set(d, mut_conds)
        feat_json.append(feat_d)
    return feat_json


exp_target_cond_df[FEAT_ANNOT] = exp_target_cond_df.apply(lambda r: get_feat_signf_assoc_cond_set_json(r, FEAT_ANNOT), axis=1)

# %%
exp_target_cond_df.to_pickle("./data/4_df.pkl")
exp_target_cond_df.shape
# Out:
# (3921, 48)
