# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = 100

# %%
import pickle
f = open("../data/ava/signif_regulon_cond_json.pkl", 'rb')   
signif_feat_cond_json = pickle.load(f)
signif_feat_cond_json[0:5]
# Out:
# [{'mutated features': 'AcrR',
#   'condition': '30 celsius',
#   'odd ratio': 8.33718588924415,
#   'p value': 2.922135087554096e-26},
#  {'mutated features': 'AcrR',
#   'condition': 'E. coli K-12 MG1655 pCA24N-fucO',
#   'odd ratio': 8.219723865877713,
#   'p value': 1.9337188814727692e-09},
#  {'mutated features': 'AcrR',
#   'condition': 'JCL260',
#   'odd ratio': 2.4943380209501234,
#   'p value': 0.0044433020223272985},
#  {'mutated features': 'AcrR',
#   'condition': 'chloramphenicol',
#   'odd ratio': 19.38630238825388,
#   'p value': 3.685307666121853e-15},
#  {'mutated features': 'AcrR',
#   'condition': 'chloramphenicol(25)',
#   'odd ratio': 8.219723865877713,
#   'p value': 1.9337188814727692e-09}]

# %%
all_muts_df = pd.read_pickle("../data/ava/4_10_with_uniq_midpts.pkl")
display(all_muts_df.shape, all_muts_df.head())
# Out:
# (5676, 52)
#   index  exp  ale  flask  isolate  tech_rep  presence  Position Mutation Type  \
# 0     9  42C    1    124        1         1       1.0    702352           DEL
# 1    10  42C    1    124        1         1       1.0   1308318           SNP
# 2    11  42C    1    124        1         1       1.0   3815859           DEL
# 3    12  42C    1    124        1         1       1.0   4187550           SNP
# 4    13  42C    1    124        1         1       1.0   4400313           SNP
#
#   Sequence Change                   Details mutation target annotation  \
# 0          Δ21 bp  coding (380‑400/1149 nt)                       nagA
# 1             G→C           R110G (CGT→GGT)                       clsA
# 2          Δ82 bp                      None                        rph
# 3             C→T           A734V (GCG→GTG)                       rpoC
# 4             A→C             D9A (GAT→GCT)                        hfq
#
# ...

# %%
FEAT = "regulators"


def get_signif_mut_conds(feat_name):
    signif_mut_conds = []
    for signif_mut_cond in signif_feat_cond_json:
        if signif_mut_cond["mutated features"] == feat_name:
            signif_mut_conds.append(signif_mut_cond)
    return signif_mut_conds


temp_df = all_muts_df.copy()
temp_df[FEAT] = temp_df.apply(lambda r: str(r[FEAT]), axis=1)

cond_mut_feat_assoc_df = pd.DataFrame()
for _, mut in all_muts_df.iterrows():
    for feat in mut[FEAT]:
        signif_mut_conds = get_signif_mut_conds(feat["name"])
        feat_name = str(feat["name"])
        df = temp_df[temp_df[FEAT].str.contains(feat_name)]
        mut_cnt = len(df)
        exp_cnt = len(df["exp"].unique())
        for d in signif_mut_conds:
            d["mutation count"] = mut_cnt
            d["experiment count"] = exp_cnt
            cond_mut_feat_assoc_df = cond_mut_feat_assoc_df.append(d, ignore_index=True)

# cond_mut_feat_assoc_df = cond_mut_feat_assoc_df.rename(columns={FEAT: "mutated genetic features"})
cond_mut_feat_assoc_df = cond_mut_feat_assoc_df.drop_duplicates()
display(len(cond_mut_feat_assoc_df), cond_mut_feat_assoc_df.head())
# Out:
# 1045
#                 condition  experiment count mutated features  mutation count  \
# 0              30 celsius              25.0             PhoP            72.0
# 1              CaCl2(0.1)              25.0             PhoP            72.0
# 2                  JCL260              25.0             PhoP            72.0
# 3  KH2PO4(3) Na2HPO4(6.8)              25.0             PhoP            72.0
# 4                      M9              25.0             PhoP            72.0
#
#    odd ratio   p value
# 0   1.705931  0.049431
# 1   1.291139  0.013590
# 2   2.014431  0.020371
# 3   1.299335  0.011830
# 4   1.291139  0.013590

# %% [markdown]
# # The below is for clustermapping

# %%
cond_cnt_d = {"none": 0}
for _, mut in all_muts_df.iterrows():
    for feat in mut[FEAT]:
        if len(feat["significantly associated conditions"]) > 0:
            for cond in feat["significantly associated conditions"]:
                if cond in cond_cnt_d.keys():                   
                    cond_cnt_d[cond] += 1
                else:
                    cond_cnt_d[cond] = 1
        else:
            cond_cnt_d["none"] += 1

cond_cnt_d
# Out:
# {'none': 3023,
#  'WT': 1445,
#  'KH2PO4(3) Na2HPO4(6.8)': 2686,
#  'CaCl2(0.1)': 2578,
#  'M9': 2578,
#  'MgSO4(0.24)': 2686,
#  'glucose(4)': 1443,
#  'NH4Cl(1)': 2699,
#  '42 celsius': 72,
#  'NaCl(0.5g/L) trace elements': 1779,
#  'U-13C glucose(2)': 22,
#  '37 celsius': 371,
#  '30 celsius': 378,
#  'ethylene glycol(30mM)': 155,
#  'E. coli K-12 MG1655 pCA24N-fucO': 155,
#  'chloramphenicol(25)': 155,
#  'glycerol(2.5)': 221,
#  'glucose(2)': 1315,
#  'FeSO4(20uM) sodium citrate(10mM)': 5,
#  'LB': 1838,
#  'JCL260': 334,
#  'isobutanol(8g/L)': 334,
#  'glucose(3)': 284,
#  'D-2-deoxyribose': 322,
#  'D-arabinose': 20,
#  'D-lyxose': 4,
#  'm-tartrate': 80,
#  'bla-TEM-1': 213,
#  'ceftazidime': 1496,
#  'pBGT': 1049,
#  'chloramphenicol': 88,
#  'doxycycline': 59,
#  'trimethoprim': 41,
#  'glucose-evolved BOP1000': 5,
#  'PQ(0.8mM)': 5,
#  'Δpgi': 97,
#  'ΔsdaA ΔsdaB ΔtdcG ΔglyA': 17,
#  "glycine(2mM) L-Serine(varying) Wolfe's vitamin solution trace elements(X1)": 17,
# ...

# %%
cond_mut_feat_assoc_df
# Out:
#                           condition  experiment count mutated features  \
# 0                        30 celsius              25.0             PhoP
# 1                        CaCl2(0.1)              25.0             PhoP
# 2                            JCL260              25.0             PhoP
# 3            KH2PO4(3) Na2HPO4(6.8)              25.0             PhoP
# 4                                M9              25.0             PhoP
# ...                             ...               ...              ...
# 106051  NaCl(0.5g/L) trace elements               2.0             PspF
# 106052           P. aerophilum tpiA               2.0             PspF
# 106053                   glucose(4)               2.0             PspF
# 121654             gentamycin(0.03)               1.0             RcnR
# 124860             gentamycin(0.03)               1.0             ZntR
#
#         mutation count  odd ratio       p value
# 0                 72.0   1.705931  4.943078e-02
# ...

# %% [markdown]
# ## Makes a clustermap for associations between Regulon and condition

# %%
signif_odds_assoc_mat = pd.DataFrame(0.0,
    index=cond_mut_feat_assoc_df["mutated features"].unique(),
    columns=cond_mut_feat_assoc_df["condition"].unique()
).astype(float)

for _, r in cond_mut_feat_assoc_df.iterrows():
    if r["p value"] <= 0.05:
        signif_odds_assoc_mat.at[r["mutated features"], r["condition"]] = r["odd ratio"]
signif_odds_assoc_mat
# Out:
#       30 celsius  CaCl2(0.1)    JCL260  KH2PO4(3) Na2HPO4(6.8)        M9  \
# PhoP    1.705931    1.291139  2.014431                1.299335  1.291139
# NagC    0.000000    1.489122  0.000000                1.498627  1.489122
# CRP     0.000000    0.000000  1.280270                0.000000  0.000000
# CsgD    0.000000    1.508351  0.000000                1.517866  1.508351
# ArgR    0.000000    0.000000  0.000000                0.000000  0.000000
# ...          ...         ...       ...                     ...       ...
# NemR    0.000000    0.000000  0.000000                0.000000  0.000000
# MhpR    0.000000    0.000000  0.000000                0.000000  0.000000
# PspF    0.000000    0.000000  0.000000                0.000000  0.000000
# RcnR    0.000000    0.000000  0.000000                0.000000  0.000000
# ZntR    0.000000    0.000000  0.000000                0.000000  0.000000
#
#       MgSO4(0.24)  P. aerophilum tpiA        WT  chloramphenicol  glucose(4)  \
# ...

# %%
# remove columns an rows of just 0s

signif_odds_assoc_mat = signif_odds_assoc_mat.loc[:, (signif_odds_assoc_mat != 0).any(axis=0)]  # remove all columns with only 0s
signif_odds_assoc_mat = signif_odds_assoc_mat.loc[(signif_odds_assoc_mat != 0).any(axis=1)]
signif_odds_assoc_mat
# Out:
#       30 celsius  CaCl2(0.1)    JCL260  KH2PO4(3) Na2HPO4(6.8)        M9  \
# PhoP    1.705931    1.291139  2.014431                1.299335  1.291139
# NagC    0.000000    1.489122  0.000000                1.498627  1.489122
# CRP     0.000000    0.000000  1.280270                0.000000  0.000000
# CsgD    0.000000    1.508351  0.000000                1.517866  1.508351
# ArgR    0.000000    0.000000  0.000000                0.000000  0.000000
# ...          ...         ...       ...                     ...       ...
# NemR    0.000000    0.000000  0.000000                0.000000  0.000000
# MhpR    0.000000    0.000000  0.000000                0.000000  0.000000
# PspF    0.000000    0.000000  0.000000                0.000000  0.000000
# RcnR    0.000000    0.000000  0.000000                0.000000  0.000000
# ZntR    0.000000    0.000000  0.000000                0.000000  0.000000
#
#       MgSO4(0.24)  P. aerophilum tpiA        WT  chloramphenicol  glucose(4)  \
# ...

# %%
signif_logodds_assoc_mat = np.log(signif_odds_assoc_mat)
signif_logodds_assoc_mat = signif_logodds_assoc_mat.replace(-np.inf, 0)
signif_logodds_assoc_mat
# Out:
# /home/pphaneuf/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
#       30 celsius  CaCl2(0.1)    JCL260  KH2PO4(3) Na2HPO4(6.8)        M9  \
# PhoP    0.534111    0.255525  0.700337                0.261853  0.255525
# NagC    0.000000    0.398187  0.000000                0.404550  0.398187
# CRP     0.000000    0.000000  0.247071                0.000000  0.000000
# CsgD    0.000000    0.411017  0.000000                0.417305  0.411017
# ArgR    0.000000    0.000000  0.000000                0.000000  0.000000
# ...          ...         ...       ...                     ...       ...
# NemR    0.000000    0.000000  0.000000                0.000000  0.000000
# MhpR    0.000000    0.000000  0.000000                0.000000  0.000000
# PspF    0.000000    0.000000  0.000000                0.000000  0.000000
# ...

# %%
signif_logodds_assoc_mat.to_pickle("../data/assocs/regs_signif_logodds_assoc_mat.pkl")
